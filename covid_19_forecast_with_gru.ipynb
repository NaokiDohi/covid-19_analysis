# %% [markdown]
# <a href="https://colab.research.google.com/github/NaokiDohi/covid-19_analysis/blob/master/covid_19_forecast_with_gru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime as dt#デフォはUTCの国際基準時間
import pytz#日本時間に変換
import time

import numpy as np
import pandas as pd
from pandas.plotting import register_matplotlib_converters
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

import statsmodels.api as sm # version 0.8.0以上
from sklearn.preprocessing import  MinMaxScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,r2_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout,GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from keras import regularizers
from keras.models import load_model
from keras import backend as K
from keras.utils import plot_model
from IPython.display import Image

from google.colab import files

# %%
path = 'COVID-19'
if not os.path.exists(path):
  # !git clone https://github.com/CSSEGISandData/COVID-19.git
else:
  print("Dude!! This file is already download")
#dataの更新は21：３０に行われる？
# Out:
# Cloning into 'COVID-19'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 62369 (delta 4), reused 9 (delta 4), pack-reused 62357
# Receiving objects: 100% (62369/62369), 528.97 MiB | 32.73 MiB/s, done.
# Resolving deltas: 100% (39823/39823), done.
# Checking out files: 100% (722/722), done.

# %%
df = pd.read_csv('COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df = df[df['Country/Region']=='Japan']
df = df.iloc[:,4:].copy()
data_at_japan = df.iloc[0,:]
data_at_japan.index = pd.to_datetime(data_at_japan.index)
print(data_at_japan)

plt.figure(figsize=(10,5))
plt.plot(data_at_japan)
plt.title("Japan COVID-19")
plt.xlabel("Date(/day)")
plt.ylabel("Person infected(/people)")
plt.grid(True)
plt.show()
# Out:
# 2020-01-22         2
# 2020-01-23         2
# 2020-01-24         2
# 2020-01-25         2
# 2020-01-26         4
#                ...
# 2020-10-30    100450
# 2020-10-31    101327
# 2020-11-01    101943
# 2020-11-02    102431
# 2020-11-03    103309
# Name: 151, Length: 287, dtype: int64

# %%
data_at_japan_diff = data_at_japan - data_at_japan.shift(1) # 階差系列データの作成
data_at_japan_diff = data_at_japan_diff.dropna()
data_at_japan_diff = data_at_japan_diff['2020-01-23':'2020-10-28']
print(data_at_japan_diff)

plt.figure(figsize=(10,5))
plt.plot(data_at_japan_diff)
plt.title('COVID-19 confilmed at Japan')
plt.xlabel("Date(/day)")
plt.ylabel("Person infected(/people)")
plt.grid()
plt.show()
# Out:
# 2020-01-23      0.0
# 2020-01-24      0.0
# 2020-01-25      0.0
# 2020-01-26      2.0
# 2020-01-27      0.0
#               ...
# 2020-10-24    731.0
# 2020-10-25    496.0
# 2020-10-26    408.0
# 2020-10-27    643.0
# 2020-10-28    731.0
# Name: 151, Length: 280, dtype: float64

# %%
hoge=data_at_japan_diff[-31:]
#print(hoge)
plt.figure(figsize=(18,8))
plt.plot(hoge)
plt.grid()
plt.show()

# %%
res = sm.tsa.seasonal_decompose(data_at_japan_diff)#データを分解

original = data_at_japan_diff # オリジナルデータ
trend_original = res.trend # トレンドデータ
seasonal_original = res.seasonal # 季節性データ
residual = res.resid # 残差データ

plt.figure(figsize=(8, 8)) # グラフ描画枠作成、サイズ指定

# オリジナルデータのプロット
plt.subplot(411) # グラフ4行1列の1番目の位置（一番上）
plt.plot(original)
plt.ylabel('Original')

# trend データのプロット
plt.subplot(412) # グラフ4行1列の2番目の位置
plt.plot(trend_original)
plt.ylabel('Trend')

# seasonalデータ のプロット
plt.subplot(413) # グラフ4行1列の3番目の位置
plt.plot(seasonal_original)
plt.ylabel('Seasonality')

# residual データのプロット
plt.subplot(414) # グラフ4行1列の4番目の位置（一番下）
plt.plot(residual)
plt.ylabel('Residuals')

plt.tight_layout() # グラフの間隔を自動調整

# %%
y = data_at_japan_diff.values.astype(float)
print(len(y))

test_size = 7
train_original_data = y[:-test_size]#0から後ろから4個目までを取り出す。　つまり学習用のデータ(学習の範囲)は直近３日間前
test_original_data = y[-test_size:]#最後から３つを取り出す。　検証用データは直近３日間前

scaler = MinMaxScaler(feature_range=(-1,1))#feature_rangeは引数に正規化変換後の最大値と最小値を決める。今回は−１から１で正規化
train_normalized = scaler.fit_transform(train_original_data.reshape(-1,1))#学習用データに正規化の適用　またskleranの入力形状に適用 合わせた行と１列
# Out:
# 280

# %%
def sequence_creator(input_data,window_size):#train_normalizedとwindow_sizeを渡し訓練データと正解ラベルを返す

    data, target = [], []
    data_len = len(input_data)
    for i in range(data_len - window_size):#data_lenのままだとwindowが配列を超えてしまう
        window_fr = input_data[i:i+window_size]#iを始点にwindow数取り出す
        correct_label = input_data[i+window_size:i+window_size+1]#index番号がi+windowの値を取り出す。つまりwindowの後にある正解ラベルを取り出す。
        data.append(window_fr)
        target.append(correct_label)

    re_data = np.array(data).reshape(len(data), window_size, 1)#kerasのRNNでは入力をサンプル数,時系列数(window数),入力層のニューロン数にする。　本来なら−１でなくlen(data)?
    re_target = np.array(target).reshape(len(target), 1)#入力と同じにする必要がある。

    return re_data, re_target

window = 7#学習時のウィンドウサイズ
study_data, correct_data  = sequence_creator(train_normalized, window)

# %%
n_in_out = 1
n_hidden = 8#2の乗数 128#256 #512

def rmse(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

model = Sequential()
model.add(GRU(n_hidden, batch_input_shape=(None, window, n_in_out), return_sequences=False,))#activation='relu',kernel_initializer='he_normal'))
#,kernel_regularizer=regularizers.l1(0.01)
#model.add(Dropout(0.2))
model.add(Dense(n_in_out))
model.add(Activation("linear"))
optimizer = Adam(lr=0.001,  amsgrad=True)
model.compile(loss="mse", optimizer=optimizer,metrics=["mae",rmse])# optimizer="rmsprop"
print(model.summary())

filename = 'gru.png';
plot_model(model, show_shapes=True, show_layer_names=True, to_file=filename)
Image(retina=False, filename=filename)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_2 (GRU)                  (None, 8)                 264
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=1)
# 学習率を返す関数を用意する
def lr_schedul(epoch):
    x = 0.001
    if epoch >= 300:
        x = 0.0005
    return x


lr_decay = LearningRateScheduler(
    lr_schedul,
    # verbose=1で、更新メッセージ表示。0の場合は表示しない
    verbose=0,
)

epochs = 700
start_time = time.time()
history = model.fit(study_data, correct_data, batch_size=1, epochs=epochs, validation_split=0.1, verbose=1, callbacks=[])#lr_decay,
print("学習時間:",time.time() - start_time)
# Out:
# Epoch 1/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.2647 - mae: 0.3987 - rmse: 0.3987 - val_loss: 0.0673 - val_mae: 0.2307 - val_rmse: 0.2307
# Epoch 2/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0500 - mae: 0.1457 - rmse: 0.1457 - val_loss: 0.0272 - val_mae: 0.1448 - val_rmse: 0.1448
# Epoch 3/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0277 - mae: 0.1023 - rmse: 0.1023 - val_loss: 0.0265 - val_mae: 0.1362 - val_rmse: 0.1362
# Epoch 4/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0255 - mae: 0.0956 - rmse: 0.0956 - val_loss: 0.0265 - val_mae: 0.1307 - val_rmse: 0.1307
# Epoch 5/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0247 - mae: 0.0939 - rmse: 0.0939 - val_loss: 0.0269 - val_mae: 0.1397 - val_rmse: 0.1397
# Epoch 6/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0244 - mae: 0.0929 - rmse: 0.0929 - val_loss: 0.0271 - val_mae: 0.1438 - val_rmse: 0.1438
# Epoch 7/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0248 - mae: 0.0949 - rmse: 0.0949 - val_loss: 0.0260 - val_mae: 0.1320 - val_rmse: 0.1320
# Epoch 8/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0238 - mae: 0.0932 - rmse: 0.0932 - val_loss: 0.0262 - val_mae: 0.1318 - val_rmse: 0.1318
# Epoch 9/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0237 - mae: 0.0907 - rmse: 0.0907 - val_loss: 0.0260 - val_mae: 0.1377 - val_rmse: 0.1377
# Epoch 10/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0232 - mae: 0.0914 - rmse: 0.0914 - val_loss: 0.0262 - val_mae: 0.1441 - val_rmse: 0.1441
# Epoch 11/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0233 - mae: 0.0928 - rmse: 0.0928 - val_loss: 0.0253 - val_mae: 0.1347 - val_rmse: 0.1347
# Epoch 12/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0232 - mae: 0.0905 - rmse: 0.0905 - val_loss: 0.0252 - val_mae: 0.1364 - val_rmse: 0.1364
# Epoch 13/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0224 - mae: 0.0923 - rmse: 0.0923 - val_loss: 0.0247 - val_mae: 0.1383 - val_rmse: 0.1383
# Epoch 14/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0226 - mae: 0.0919 - rmse: 0.0919 - val_loss: 0.0256 - val_mae: 0.1440 - val_rmse: 0.1440
# Epoch 15/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0223 - mae: 0.0901 - rmse: 0.0901 - val_loss: 0.0245 - val_mae: 0.1247 - val_rmse: 0.1247
# Epoch 16/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0226 - mae: 0.0908 - rmse: 0.0908 - val_loss: 0.0245 - val_mae: 0.1389 - val_rmse: 0.1389
# Epoch 17/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0215 - mae: 0.0887 - rmse: 0.0887 - val_loss: 0.0261 - val_mae: 0.1476 - val_rmse: 0.1476
# Epoch 18/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0220 - mae: 0.0911 - rmse: 0.0911 - val_loss: 0.0236 - val_mae: 0.1371 - val_rmse: 0.1371
# Epoch 19/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0213 - mae: 0.0878 - rmse: 0.0878 - val_loss: 0.0230 - val_mae: 0.1281 - val_rmse: 0.1281
# Epoch 20/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0215 - mae: 0.0869 - rmse: 0.0869 - val_loss: 0.0225 - val_mae: 0.1290 - val_rmse: 0.1290
# Epoch 21/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0216 - mae: 0.0895 - rmse: 0.0895 - val_loss: 0.0228 - val_mae: 0.1348 - val_rmse: 0.1348
# Epoch 22/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0215 - mae: 0.0887 - rmse: 0.0887 - val_loss: 0.0229 - val_mae: 0.1365 - val_rmse: 0.1365
# Epoch 23/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0210 - mae: 0.0887 - rmse: 0.0887 - val_loss: 0.0221 - val_mae: 0.1254 - val_rmse: 0.1254
# Epoch 24/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0207 - mae: 0.0864 - rmse: 0.0864 - val_loss: 0.0220 - val_mae: 0.1303 - val_rmse: 0.1303
# Epoch 25/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0210 - mae: 0.0887 - rmse: 0.0887 - val_loss: 0.0218 - val_mae: 0.1284 - val_rmse: 0.1284
# Epoch 26/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0207 - mae: 0.0893 - rmse: 0.0893 - val_loss: 0.0215 - val_mae: 0.1272 - val_rmse: 0.1272
# Epoch 27/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0204 - mae: 0.0851 - rmse: 0.0851 - val_loss: 0.0213 - val_mae: 0.1300 - val_rmse: 0.1300
# Epoch 28/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0208 - mae: 0.0873 - rmse: 0.0873 - val_loss: 0.0211 - val_mae: 0.1252 - val_rmse: 0.1252
# Epoch 29/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0205 - mae: 0.0845 - rmse: 0.0845 - val_loss: 0.0214 - val_mae: 0.1310 - val_rmse: 0.1310
# Epoch 30/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0206 - mae: 0.0864 - rmse: 0.0864 - val_loss: 0.0210 - val_mae: 0.1250 - val_rmse: 0.1250
# Epoch 31/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0203 - mae: 0.0871 - rmse: 0.0871 - val_loss: 0.0212 - val_mae: 0.1214 - val_rmse: 0.1214
# Epoch 32/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0206 - mae: 0.0852 - rmse: 0.0852 - val_loss: 0.0212 - val_mae: 0.1205 - val_rmse: 0.1205
# Epoch 33/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0203 - mae: 0.0888 - rmse: 0.0888 - val_loss: 0.0206 - val_mae: 0.1244 - val_rmse: 0.1244
# Epoch 34/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0205 - mae: 0.0880 - rmse: 0.0880 - val_loss: 0.0203 - val_mae: 0.1211 - val_rmse: 0.1211
# Epoch 35/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0204 - mae: 0.0873 - rmse: 0.0873 - val_loss: 0.0203 - val_mae: 0.1228 - val_rmse: 0.1228
# Epoch 36/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0201 - mae: 0.0867 - rmse: 0.0867 - val_loss: 0.0206 - val_mae: 0.1275 - val_rmse: 0.1275
# Epoch 37/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0205 - mae: 0.0860 - rmse: 0.0860 - val_loss: 0.0203 - val_mae: 0.1265 - val_rmse: 0.1265
# Epoch 38/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0203 - mae: 0.0863 - rmse: 0.0863 - val_loss: 0.0209 - val_mae: 0.1290 - val_rmse: 0.1290
# Epoch 39/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0859 - rmse: 0.0859 - val_loss: 0.0201 - val_mae: 0.1200 - val_rmse: 0.1200
# Epoch 40/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0847 - rmse: 0.0847 - val_loss: 0.0201 - val_mae: 0.1249 - val_rmse: 0.1249
# Epoch 41/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0201 - mae: 0.0862 - rmse: 0.0862 - val_loss: 0.0200 - val_mae: 0.1222 - val_rmse: 0.1222
# Epoch 42/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0855 - rmse: 0.0855 - val_loss: 0.0205 - val_mae: 0.1280 - val_rmse: 0.1280
# Epoch 43/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0864 - rmse: 0.0864 - val_loss: 0.0207 - val_mae: 0.1294 - val_rmse: 0.1294
# Epoch 44/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0200 - mae: 0.0854 - rmse: 0.0854 - val_loss: 0.0200 - val_mae: 0.1236 - val_rmse: 0.1236
# Epoch 45/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0838 - rmse: 0.0838 - val_loss: 0.0197 - val_mae: 0.1244 - val_rmse: 0.1244
# Epoch 46/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0860 - rmse: 0.0860 - val_loss: 0.0197 - val_mae: 0.1226 - val_rmse: 0.1226
# Epoch 47/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0855 - rmse: 0.0855 - val_loss: 0.0210 - val_mae: 0.1311 - val_rmse: 0.1311
# Epoch 48/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0205 - mae: 0.0855 - rmse: 0.0855 - val_loss: 0.0197 - val_mae: 0.1235 - val_rmse: 0.1235
# Epoch 49/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0847 - rmse: 0.0847 - val_loss: 0.0193 - val_mae: 0.1195 - val_rmse: 0.1195
# Epoch 50/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0200 - mae: 0.0859 - rmse: 0.0859 - val_loss: 0.0195 - val_mae: 0.1208 - val_rmse: 0.1208
# Epoch 51/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0196 - mae: 0.0839 - rmse: 0.0839 - val_loss: 0.0197 - val_mae: 0.1242 - val_rmse: 0.1242
# Epoch 52/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0854 - rmse: 0.0854 - val_loss: 0.0195 - val_mae: 0.1230 - val_rmse: 0.1230
# Epoch 53/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0201 - mae: 0.0896 - rmse: 0.0896 - val_loss: 0.0194 - val_mae: 0.1222 - val_rmse: 0.1222
# Epoch 54/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0852 - rmse: 0.0852 - val_loss: 0.0199 - val_mae: 0.1257 - val_rmse: 0.1257
# Epoch 55/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0860 - rmse: 0.0860 - val_loss: 0.0204 - val_mae: 0.1283 - val_rmse: 0.1283
# Epoch 56/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0194 - mae: 0.0838 - rmse: 0.0838 - val_loss: 0.0197 - val_mae: 0.1196 - val_rmse: 0.1196
# Epoch 57/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0198 - mae: 0.0859 - rmse: 0.0859 - val_loss: 0.0196 - val_mae: 0.1228 - val_rmse: 0.1228
# Epoch 58/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0855 - rmse: 0.0855 - val_loss: 0.0193 - val_mae: 0.1210 - val_rmse: 0.1210
# Epoch 59/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0192 - mae: 0.0843 - rmse: 0.0843 - val_loss: 0.0201 - val_mae: 0.1194 - val_rmse: 0.1194
# Epoch 60/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0200 - mae: 0.0882 - rmse: 0.0882 - val_loss: 0.0194 - val_mae: 0.1194 - val_rmse: 0.1194
# Epoch 61/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0852 - rmse: 0.0852 - val_loss: 0.0205 - val_mae: 0.1284 - val_rmse: 0.1284
# Epoch 62/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0196 - mae: 0.0860 - rmse: 0.0860 - val_loss: 0.0205 - val_mae: 0.1290 - val_rmse: 0.1290
# Epoch 63/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0194 - mae: 0.0847 - rmse: 0.0847 - val_loss: 0.0193 - val_mae: 0.1189 - val_rmse: 0.1189
# Epoch 64/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0188 - mae: 0.0879 - rmse: 0.0879 - val_loss: 0.0198 - val_mae: 0.1264 - val_rmse: 0.1264
# Epoch 65/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0199 - mae: 0.0878 - rmse: 0.0878 - val_loss: 0.0194 - val_mae: 0.1224 - val_rmse: 0.1224
# Epoch 66/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0192 - mae: 0.0842 - rmse: 0.0842 - val_loss: 0.0197 - val_mae: 0.1236 - val_rmse: 0.1236
# Epoch 67/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0195 - mae: 0.0849 - rmse: 0.0849 - val_loss: 0.0202 - val_mae: 0.1263 - val_rmse: 0.1263
# Epoch 68/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0840 - rmse: 0.0840 - val_loss: 0.0193 - val_mae: 0.1220 - val_rmse: 0.1220
# Epoch 69/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0847 - rmse: 0.0847 - val_loss: 0.0202 - val_mae: 0.1272 - val_rmse: 0.1272
# Epoch 70/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0194 - mae: 0.0845 - rmse: 0.0845 - val_loss: 0.0203 - val_mae: 0.1275 - val_rmse: 0.1275
# Epoch 71/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0834 - rmse: 0.0834 - val_loss: 0.0195 - val_mae: 0.1222 - val_rmse: 0.1222
# Epoch 72/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0195 - mae: 0.0854 - rmse: 0.0854 - val_loss: 0.0193 - val_mae: 0.1221 - val_rmse: 0.1221
# Epoch 73/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0194 - mae: 0.0848 - rmse: 0.0848 - val_loss: 0.0193 - val_mae: 0.1218 - val_rmse: 0.1218
# Epoch 74/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0856 - rmse: 0.0856 - val_loss: 0.0198 - val_mae: 0.1253 - val_rmse: 0.1253
# Epoch 75/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0195 - mae: 0.0866 - rmse: 0.0866 - val_loss: 0.0191 - val_mae: 0.1181 - val_rmse: 0.1181
# Epoch 76/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0866 - rmse: 0.0866 - val_loss: 0.0197 - val_mae: 0.1248 - val_rmse: 0.1248
# Epoch 77/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0191 - mae: 0.0842 - rmse: 0.0842 - val_loss: 0.0193 - val_mae: 0.1211 - val_rmse: 0.1211
# Epoch 78/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0842 - rmse: 0.0842 - val_loss: 0.0200 - val_mae: 0.1256 - val_rmse: 0.1256
# Epoch 79/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0191 - mae: 0.0851 - rmse: 0.0851 - val_loss: 0.0200 - val_mae: 0.1253 - val_rmse: 0.1253
# Epoch 80/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0190 - mae: 0.0831 - rmse: 0.0831 - val_loss: 0.0193 - val_mae: 0.1227 - val_rmse: 0.1227
# Epoch 81/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.0841 - rmse: 0.0841 - val_loss: 0.0199 - val_mae: 0.1237 - val_rmse: 0.1237
# Epoch 82/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0190 - mae: 0.0838 - rmse: 0.0838 - val_loss: 0.0197 - val_mae: 0.1225 - val_rmse: 0.1225
# Epoch 83/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0191 - mae: 0.0834 - rmse: 0.0834 - val_loss: 0.0192 - val_mae: 0.1221 - val_rmse: 0.1221
# Epoch 84/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0188 - mae: 0.0826 - rmse: 0.0826 - val_loss: 0.0197 - val_mae: 0.1204 - val_rmse: 0.1204
# Epoch 85/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0189 - mae: 0.0844 - rmse: 0.0844 - val_loss: 0.0198 - val_mae: 0.1238 - val_rmse: 0.1238
# Epoch 86/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0188 - mae: 0.0842 - rmse: 0.0842 - val_loss: 0.0196 - val_mae: 0.1240 - val_rmse: 0.1240
# Epoch 87/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0188 - mae: 0.0838 - rmse: 0.0838 - val_loss: 0.0202 - val_mae: 0.1265 - val_rmse: 0.1265
# Epoch 88/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0190 - mae: 0.0831 - rmse: 0.0831 - val_loss: 0.0195 - val_mae: 0.1228 - val_rmse: 0.1228
# Epoch 89/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.0838 - rmse: 0.0838 - val_loss: 0.0194 - val_mae: 0.1214 - val_rmse: 0.1214
# Epoch 90/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.0842 - rmse: 0.0842 - val_loss: 0.0197 - val_mae: 0.1237 - val_rmse: 0.1237
# Epoch 91/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0185 - mae: 0.0824 - rmse: 0.0824 - val_loss: 0.0196 - val_mae: 0.1199 - val_rmse: 0.1199
# Epoch 92/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.0840 - rmse: 0.0840 - val_loss: 0.0194 - val_mae: 0.1223 - val_rmse: 0.1223
# Epoch 93/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0185 - mae: 0.0836 - rmse: 0.0836 - val_loss: 0.0207 - val_mae: 0.1294 - val_rmse: 0.1294
# Epoch 94/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.0847 - rmse: 0.0847 - val_loss: 0.0192 - val_mae: 0.1221 - val_rmse: 0.1221
# Epoch 95/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0185 - mae: 0.0837 - rmse: 0.0837 - val_loss: 0.0194 - val_mae: 0.1200 - val_rmse: 0.1200
# Epoch 96/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0185 - mae: 0.0829 - rmse: 0.0829 - val_loss: 0.0198 - val_mae: 0.1233 - val_rmse: 0.1233
# Epoch 97/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0183 - mae: 0.0815 - rmse: 0.0815 - val_loss: 0.0195 - val_mae: 0.1232 - val_rmse: 0.1232
# Epoch 98/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0186 - mae: 0.0838 - rmse: 0.0838 - val_loss: 0.0195 - val_mae: 0.1224 - val_rmse: 0.1224
# Epoch 99/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0184 - mae: 0.0835 - rmse: 0.0835 - val_loss: 0.0204 - val_mae: 0.1273 - val_rmse: 0.1273
# Epoch 100/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0182 - mae: 0.0812 - rmse: 0.0812 - val_loss: 0.0211 - val_mae: 0.1309 - val_rmse: 0.1309
# Epoch 101/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0184 - mae: 0.0824 - rmse: 0.0824 - val_loss: 0.0195 - val_mae: 0.1226 - val_rmse: 0.1226
# Epoch 102/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0181 - mae: 0.0824 - rmse: 0.0824 - val_loss: 0.0197 - val_mae: 0.1211 - val_rmse: 0.1211
# Epoch 103/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0181 - mae: 0.0817 - rmse: 0.0817 - val_loss: 0.0194 - val_mae: 0.1215 - val_rmse: 0.1215
# Epoch 104/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0181 - mae: 0.0824 - rmse: 0.0824 - val_loss: 0.0202 - val_mae: 0.1260 - val_rmse: 0.1260
# Epoch 105/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0181 - mae: 0.0829 - rmse: 0.0829 - val_loss: 0.0199 - val_mae: 0.1238 - val_rmse: 0.1238
# Epoch 106/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0179 - mae: 0.0823 - rmse: 0.0823 - val_loss: 0.0193 - val_mae: 0.1217 - val_rmse: 0.1217
# Epoch 107/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0180 - mae: 0.0792 - rmse: 0.0792 - val_loss: 0.0190 - val_mae: 0.1208 - val_rmse: 0.1208
# Epoch 108/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0179 - mae: 0.0816 - rmse: 0.0816 - val_loss: 0.0198 - val_mae: 0.1246 - val_rmse: 0.1246
# Epoch 109/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0177 - mae: 0.0822 - rmse: 0.0822 - val_loss: 0.0193 - val_mae: 0.1215 - val_rmse: 0.1215
# Epoch 110/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0178 - mae: 0.0805 - rmse: 0.0805 - val_loss: 0.0199 - val_mae: 0.1249 - val_rmse: 0.1249
# Epoch 111/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0176 - mae: 0.0803 - rmse: 0.0803 - val_loss: 0.0196 - val_mae: 0.1230 - val_rmse: 0.1230
# Epoch 112/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0174 - mae: 0.0806 - rmse: 0.0806 - val_loss: 0.0194 - val_mae: 0.1229 - val_rmse: 0.1229
# Epoch 113/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.0799 - rmse: 0.0799 - val_loss: 0.0194 - val_mae: 0.1229 - val_rmse: 0.1229
# Epoch 114/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0172 - mae: 0.0810 - rmse: 0.0810 - val_loss: 0.0193 - val_mae: 0.1224 - val_rmse: 0.1224
# Epoch 115/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0173 - mae: 0.0791 - rmse: 0.0791 - val_loss: 0.0192 - val_mae: 0.1217 - val_rmse: 0.1217
# Epoch 116/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0171 - mae: 0.0798 - rmse: 0.0798 - val_loss: 0.0191 - val_mae: 0.1209 - val_rmse: 0.1209
# Epoch 117/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0170 - mae: 0.0786 - rmse: 0.0786 - val_loss: 0.0188 - val_mae: 0.1200 - val_rmse: 0.1200
# Epoch 118/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0172 - mae: 0.0812 - rmse: 0.0812 - val_loss: 0.0190 - val_mae: 0.1202 - val_rmse: 0.1202
# Epoch 119/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0170 - mae: 0.0784 - rmse: 0.0784 - val_loss: 0.0189 - val_mae: 0.1203 - val_rmse: 0.1203
# Epoch 120/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0170 - mae: 0.0787 - rmse: 0.0787 - val_loss: 0.0184 - val_mae: 0.1183 - val_rmse: 0.1183
# Epoch 121/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0166 - mae: 0.0779 - rmse: 0.0779 - val_loss: 0.0194 - val_mae: 0.1222 - val_rmse: 0.1222
# Epoch 122/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0168 - mae: 0.0795 - rmse: 0.0795 - val_loss: 0.0191 - val_mae: 0.1211 - val_rmse: 0.1211
# Epoch 123/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0166 - mae: 0.0765 - rmse: 0.0765 - val_loss: 0.0185 - val_mae: 0.1193 - val_rmse: 0.1193
# Epoch 124/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0165 - mae: 0.0763 - rmse: 0.0763 - val_loss: 0.0182 - val_mae: 0.1177 - val_rmse: 0.1177
# Epoch 125/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0162 - mae: 0.0775 - rmse: 0.0775 - val_loss: 0.0194 - val_mae: 0.1217 - val_rmse: 0.1217
# Epoch 126/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0162 - mae: 0.0758 - rmse: 0.0758 - val_loss: 0.0183 - val_mae: 0.1176 - val_rmse: 0.1176
# Epoch 127/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0163 - mae: 0.0795 - rmse: 0.0795 - val_loss: 0.0181 - val_mae: 0.1175 - val_rmse: 0.1175
# Epoch 128/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0156 - mae: 0.0755 - rmse: 0.0755 - val_loss: 0.0179 - val_mae: 0.1159 - val_rmse: 0.1159
# Epoch 129/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0159 - mae: 0.0752 - rmse: 0.0752 - val_loss: 0.0183 - val_mae: 0.1180 - val_rmse: 0.1180
# Epoch 130/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0158 - mae: 0.0761 - rmse: 0.0761 - val_loss: 0.0177 - val_mae: 0.1156 - val_rmse: 0.1156
# Epoch 131/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0159 - mae: 0.0762 - rmse: 0.0762 - val_loss: 0.0190 - val_mae: 0.1187 - val_rmse: 0.1187
# Epoch 132/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0155 - mae: 0.0746 - rmse: 0.0746 - val_loss: 0.0183 - val_mae: 0.1168 - val_rmse: 0.1168
# Epoch 133/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0158 - mae: 0.0752 - rmse: 0.0752 - val_loss: 0.0181 - val_mae: 0.1152 - val_rmse: 0.1152
# Epoch 134/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0157 - mae: 0.0755 - rmse: 0.0755 - val_loss: 0.0180 - val_mae: 0.1162 - val_rmse: 0.1162
# Epoch 135/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0152 - mae: 0.0723 - rmse: 0.0723 - val_loss: 0.0177 - val_mae: 0.1142 - val_rmse: 0.1142
# Epoch 136/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0155 - mae: 0.0759 - rmse: 0.0759 - val_loss: 0.0173 - val_mae: 0.1121 - val_rmse: 0.1121
# Epoch 137/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0156 - mae: 0.0746 - rmse: 0.0746 - val_loss: 0.0179 - val_mae: 0.1144 - val_rmse: 0.1144
# Epoch 138/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0153 - mae: 0.0739 - rmse: 0.0739 - val_loss: 0.0190 - val_mae: 0.1181 - val_rmse: 0.1181
# Epoch 139/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0154 - mae: 0.0747 - rmse: 0.0747 - val_loss: 0.0183 - val_mae: 0.1159 - val_rmse: 0.1159
# Epoch 140/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0153 - mae: 0.0745 - rmse: 0.0745 - val_loss: 0.0178 - val_mae: 0.1132 - val_rmse: 0.1132
# Epoch 141/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0152 - mae: 0.0726 - rmse: 0.0726 - val_loss: 0.0174 - val_mae: 0.1132 - val_rmse: 0.1132
# Epoch 142/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0149 - mae: 0.0742 - rmse: 0.0742 - val_loss: 0.0186 - val_mae: 0.1161 - val_rmse: 0.1161
# Epoch 143/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0153 - mae: 0.0745 - rmse: 0.0745 - val_loss: 0.0173 - val_mae: 0.1138 - val_rmse: 0.1138
# Epoch 144/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0151 - mae: 0.0730 - rmse: 0.0730 - val_loss: 0.0176 - val_mae: 0.1139 - val_rmse: 0.1139
# Epoch 145/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0151 - mae: 0.0726 - rmse: 0.0726 - val_loss: 0.0176 - val_mae: 0.1141 - val_rmse: 0.1141
# Epoch 146/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0149 - mae: 0.0737 - rmse: 0.0737 - val_loss: 0.0168 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 147/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0149 - mae: 0.0730 - rmse: 0.0730 - val_loss: 0.0170 - val_mae: 0.1108 - val_rmse: 0.1108
# Epoch 148/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0147 - mae: 0.0726 - rmse: 0.0726 - val_loss: 0.0166 - val_mae: 0.1104 - val_rmse: 0.1104
# Epoch 149/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0150 - mae: 0.0723 - rmse: 0.0723 - val_loss: 0.0172 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 150/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0146 - mae: 0.0716 - rmse: 0.0716 - val_loss: 0.0168 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 151/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0148 - mae: 0.0732 - rmse: 0.0732 - val_loss: 0.0166 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 152/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0147 - mae: 0.0745 - rmse: 0.0745 - val_loss: 0.0170 - val_mae: 0.1098 - val_rmse: 0.1098
# Epoch 153/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0146 - mae: 0.0719 - rmse: 0.0719 - val_loss: 0.0165 - val_mae: 0.1102 - val_rmse: 0.1102
# Epoch 154/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0148 - mae: 0.0727 - rmse: 0.0727 - val_loss: 0.0166 - val_mae: 0.1104 - val_rmse: 0.1104
# Epoch 155/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0146 - mae: 0.0706 - rmse: 0.0706 - val_loss: 0.0172 - val_mae: 0.1096 - val_rmse: 0.1096
# Epoch 156/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0145 - mae: 0.0713 - rmse: 0.0713 - val_loss: 0.0164 - val_mae: 0.1092 - val_rmse: 0.1092
# Epoch 157/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0148 - mae: 0.0754 - rmse: 0.0754 - val_loss: 0.0168 - val_mae: 0.1113 - val_rmse: 0.1113
# Epoch 158/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0146 - mae: 0.0727 - rmse: 0.0727 - val_loss: 0.0172 - val_mae: 0.1130 - val_rmse: 0.1130
# Epoch 159/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0144 - mae: 0.0721 - rmse: 0.0721 - val_loss: 0.0170 - val_mae: 0.1120 - val_rmse: 0.1120
# Epoch 160/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0144 - mae: 0.0721 - rmse: 0.0721 - val_loss: 0.0176 - val_mae: 0.1134 - val_rmse: 0.1134
# Epoch 161/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0144 - mae: 0.0715 - rmse: 0.0715 - val_loss: 0.0166 - val_mae: 0.1102 - val_rmse: 0.1102
# Epoch 162/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0144 - mae: 0.0702 - rmse: 0.0702 - val_loss: 0.0173 - val_mae: 0.1115 - val_rmse: 0.1115
# Epoch 163/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0145 - mae: 0.0719 - rmse: 0.0719 - val_loss: 0.0165 - val_mae: 0.1089 - val_rmse: 0.1089
# Epoch 164/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0143 - mae: 0.0705 - rmse: 0.0705 - val_loss: 0.0163 - val_mae: 0.1078 - val_rmse: 0.1078
# Epoch 165/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0140 - mae: 0.0702 - rmse: 0.0702 - val_loss: 0.0162 - val_mae: 0.1082 - val_rmse: 0.1082
# Epoch 166/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0143 - mae: 0.0715 - rmse: 0.0715 - val_loss: 0.0171 - val_mae: 0.1104 - val_rmse: 0.1104
# Epoch 167/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0142 - mae: 0.0715 - rmse: 0.0715 - val_loss: 0.0159 - val_mae: 0.1061 - val_rmse: 0.1061
# Epoch 168/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0143 - mae: 0.0736 - rmse: 0.0736 - val_loss: 0.0166 - val_mae: 0.1086 - val_rmse: 0.1086
# Epoch 169/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0141 - mae: 0.0718 - rmse: 0.0718 - val_loss: 0.0169 - val_mae: 0.1097 - val_rmse: 0.1097
# Epoch 170/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0141 - mae: 0.0713 - rmse: 0.0713 - val_loss: 0.0163 - val_mae: 0.1079 - val_rmse: 0.1079
# Epoch 171/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0139 - mae: 0.0698 - rmse: 0.0698 - val_loss: 0.0168 - val_mae: 0.1102 - val_rmse: 0.1102
# Epoch 172/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0141 - mae: 0.0696 - rmse: 0.0696 - val_loss: 0.0161 - val_mae: 0.1085 - val_rmse: 0.1085
# Epoch 173/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0139 - mae: 0.0719 - rmse: 0.0719 - val_loss: 0.0168 - val_mae: 0.1112 - val_rmse: 0.1112
# Epoch 174/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0142 - mae: 0.0706 - rmse: 0.0706 - val_loss: 0.0165 - val_mae: 0.1103 - val_rmse: 0.1103
# Epoch 175/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0141 - mae: 0.0708 - rmse: 0.0708 - val_loss: 0.0163 - val_mae: 0.1097 - val_rmse: 0.1097
# Epoch 176/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0140 - mae: 0.0701 - rmse: 0.0701 - val_loss: 0.0164 - val_mae: 0.1087 - val_rmse: 0.1087
# Epoch 177/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0138 - mae: 0.0693 - rmse: 0.0693 - val_loss: 0.0161 - val_mae: 0.1079 - val_rmse: 0.1079
# Epoch 178/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0138 - mae: 0.0696 - rmse: 0.0696 - val_loss: 0.0156 - val_mae: 0.1060 - val_rmse: 0.1060
# Epoch 179/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0140 - mae: 0.0707 - rmse: 0.0707 - val_loss: 0.0164 - val_mae: 0.1092 - val_rmse: 0.1092
# Epoch 180/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0137 - mae: 0.0694 - rmse: 0.0694 - val_loss: 0.0159 - val_mae: 0.1070 - val_rmse: 0.1070
# Epoch 181/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0140 - mae: 0.0706 - rmse: 0.0706 - val_loss: 0.0167 - val_mae: 0.1109 - val_rmse: 0.1109
# Epoch 182/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0138 - mae: 0.0713 - rmse: 0.0713 - val_loss: 0.0170 - val_mae: 0.1110 - val_rmse: 0.1110
# Epoch 183/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0135 - mae: 0.0689 - rmse: 0.0689 - val_loss: 0.0166 - val_mae: 0.1096 - val_rmse: 0.1096
# Epoch 184/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0138 - mae: 0.0691 - rmse: 0.0691 - val_loss: 0.0160 - val_mae: 0.1068 - val_rmse: 0.1068
# Epoch 185/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0138 - mae: 0.0707 - rmse: 0.0707 - val_loss: 0.0162 - val_mae: 0.1080 - val_rmse: 0.1080
# Epoch 186/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0133 - mae: 0.0678 - rmse: 0.0678 - val_loss: 0.0168 - val_mae: 0.1072 - val_rmse: 0.1072
# Epoch 187/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0133 - mae: 0.0683 - rmse: 0.0683 - val_loss: 0.0158 - val_mae: 0.1074 - val_rmse: 0.1074
# Epoch 188/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0135 - mae: 0.0691 - rmse: 0.0691 - val_loss: 0.0163 - val_mae: 0.1093 - val_rmse: 0.1093
# Epoch 189/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0135 - mae: 0.0685 - rmse: 0.0685 - val_loss: 0.0159 - val_mae: 0.1067 - val_rmse: 0.1067
# Epoch 190/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0131 - mae: 0.0685 - rmse: 0.0685 - val_loss: 0.0165 - val_mae: 0.1102 - val_rmse: 0.1102
# Epoch 191/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0134 - mae: 0.0694 - rmse: 0.0694 - val_loss: 0.0158 - val_mae: 0.1061 - val_rmse: 0.1061
# Epoch 192/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0134 - mae: 0.0686 - rmse: 0.0686 - val_loss: 0.0162 - val_mae: 0.1084 - val_rmse: 0.1084
# Epoch 193/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0131 - mae: 0.0680 - rmse: 0.0680 - val_loss: 0.0170 - val_mae: 0.1116 - val_rmse: 0.1116
# Epoch 194/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0131 - mae: 0.0669 - rmse: 0.0669 - val_loss: 0.0163 - val_mae: 0.1088 - val_rmse: 0.1088
# Epoch 195/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0132 - mae: 0.0677 - rmse: 0.0677 - val_loss: 0.0162 - val_mae: 0.1076 - val_rmse: 0.1076
# Epoch 196/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0130 - mae: 0.0678 - rmse: 0.0678 - val_loss: 0.0163 - val_mae: 0.1087 - val_rmse: 0.1087
# Epoch 197/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0130 - mae: 0.0679 - rmse: 0.0679 - val_loss: 0.0159 - val_mae: 0.1067 - val_rmse: 0.1067
# Epoch 198/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0130 - mae: 0.0664 - rmse: 0.0664 - val_loss: 0.0156 - val_mae: 0.1063 - val_rmse: 0.1063
# Epoch 199/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0130 - mae: 0.0671 - rmse: 0.0671 - val_loss: 0.0158 - val_mae: 0.1070 - val_rmse: 0.1070
# Epoch 200/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0128 - mae: 0.0673 - rmse: 0.0673 - val_loss: 0.0164 - val_mae: 0.1094 - val_rmse: 0.1094
# Epoch 201/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0129 - mae: 0.0676 - rmse: 0.0676 - val_loss: 0.0151 - val_mae: 0.1037 - val_rmse: 0.1037
# Epoch 202/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0131 - mae: 0.0684 - rmse: 0.0684 - val_loss: 0.0165 - val_mae: 0.1051 - val_rmse: 0.1051
# Epoch 203/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0131 - mae: 0.0674 - rmse: 0.0674 - val_loss: 0.0157 - val_mae: 0.1057 - val_rmse: 0.1057
# Epoch 204/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0128 - mae: 0.0672 - rmse: 0.0672 - val_loss: 0.0162 - val_mae: 0.1070 - val_rmse: 0.1070
# Epoch 205/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0129 - mae: 0.0680 - rmse: 0.0680 - val_loss: 0.0156 - val_mae: 0.1053 - val_rmse: 0.1053
# Epoch 206/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0128 - mae: 0.0679 - rmse: 0.0679 - val_loss: 0.0156 - val_mae: 0.1050 - val_rmse: 0.1050
# Epoch 207/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0126 - mae: 0.0686 - rmse: 0.0686 - val_loss: 0.0167 - val_mae: 0.1091 - val_rmse: 0.1091
# Epoch 208/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0124 - mae: 0.0660 - rmse: 0.0660 - val_loss: 0.0151 - val_mae: 0.1021 - val_rmse: 0.1021
# Epoch 209/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0129 - mae: 0.0667 - rmse: 0.0667 - val_loss: 0.0160 - val_mae: 0.1069 - val_rmse: 0.1069
# Epoch 210/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0126 - mae: 0.0682 - rmse: 0.0682 - val_loss: 0.0176 - val_mae: 0.1137 - val_rmse: 0.1137
# Epoch 211/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0124 - mae: 0.0652 - rmse: 0.0652 - val_loss: 0.0150 - val_mae: 0.1030 - val_rmse: 0.1030
# Epoch 212/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0126 - mae: 0.0674 - rmse: 0.0674 - val_loss: 0.0154 - val_mae: 0.1046 - val_rmse: 0.1046
# Epoch 213/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0124 - mae: 0.0652 - rmse: 0.0652 - val_loss: 0.0156 - val_mae: 0.1050 - val_rmse: 0.1050
# Epoch 214/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0124 - mae: 0.0660 - rmse: 0.0660 - val_loss: 0.0162 - val_mae: 0.1076 - val_rmse: 0.1076
# Epoch 215/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0123 - mae: 0.0666 - rmse: 0.0666 - val_loss: 0.0176 - val_mae: 0.1135 - val_rmse: 0.1135
# Epoch 216/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0120 - mae: 0.0669 - rmse: 0.0669 - val_loss: 0.0150 - val_mae: 0.1029 - val_rmse: 0.1029
# Epoch 217/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0124 - mae: 0.0667 - rmse: 0.0667 - val_loss: 0.0155 - val_mae: 0.1043 - val_rmse: 0.1043
# Epoch 218/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0122 - mae: 0.0667 - rmse: 0.0667 - val_loss: 0.0163 - val_mae: 0.1076 - val_rmse: 0.1076
# Epoch 219/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0122 - mae: 0.0670 - rmse: 0.0670 - val_loss: 0.0168 - val_mae: 0.1091 - val_rmse: 0.1091
# Epoch 220/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0123 - mae: 0.0663 - rmse: 0.0663 - val_loss: 0.0163 - val_mae: 0.1075 - val_rmse: 0.1075
# Epoch 221/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0120 - mae: 0.0648 - rmse: 0.0648 - val_loss: 0.0189 - val_mae: 0.1168 - val_rmse: 0.1168
# Epoch 222/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0124 - mae: 0.0658 - rmse: 0.0658 - val_loss: 0.0188 - val_mae: 0.1169 - val_rmse: 0.1169
# Epoch 223/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0122 - mae: 0.0659 - rmse: 0.0659 - val_loss: 0.0165 - val_mae: 0.1093 - val_rmse: 0.1093
# Epoch 224/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0121 - mae: 0.0660 - rmse: 0.0660 - val_loss: 0.0192 - val_mae: 0.1188 - val_rmse: 0.1188
# Epoch 225/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0121 - mae: 0.0659 - rmse: 0.0659 - val_loss: 0.0157 - val_mae: 0.1062 - val_rmse: 0.1062
# Epoch 226/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0120 - mae: 0.0653 - rmse: 0.0653 - val_loss: 0.0172 - val_mae: 0.1112 - val_rmse: 0.1112
# Epoch 227/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0118 - mae: 0.0642 - rmse: 0.0642 - val_loss: 0.0152 - val_mae: 0.1038 - val_rmse: 0.1038
# Epoch 228/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0120 - mae: 0.0665 - rmse: 0.0665 - val_loss: 0.0163 - val_mae: 0.1077 - val_rmse: 0.1077
# Epoch 229/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0117 - mae: 0.0653 - rmse: 0.0653 - val_loss: 0.0158 - val_mae: 0.1050 - val_rmse: 0.1050
# Epoch 230/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0119 - mae: 0.0652 - rmse: 0.0652 - val_loss: 0.0165 - val_mae: 0.1084 - val_rmse: 0.1084
# Epoch 231/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0119 - mae: 0.0649 - rmse: 0.0649 - val_loss: 0.0159 - val_mae: 0.1043 - val_rmse: 0.1043
# Epoch 232/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0118 - mae: 0.0653 - rmse: 0.0653 - val_loss: 0.0165 - val_mae: 0.1077 - val_rmse: 0.1077
# Epoch 233/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0114 - mae: 0.0645 - rmse: 0.0645 - val_loss: 0.0157 - val_mae: 0.1043 - val_rmse: 0.1043
# Epoch 234/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0118 - mae: 0.0650 - rmse: 0.0650 - val_loss: 0.0162 - val_mae: 0.1064 - val_rmse: 0.1064
# Epoch 235/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0114 - mae: 0.0646 - rmse: 0.0646 - val_loss: 0.0154 - val_mae: 0.1036 - val_rmse: 0.1036
# Epoch 236/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0116 - mae: 0.0641 - rmse: 0.0641 - val_loss: 0.0177 - val_mae: 0.1131 - val_rmse: 0.1131
# Epoch 237/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0114 - mae: 0.0651 - rmse: 0.0651 - val_loss: 0.0170 - val_mae: 0.1092 - val_rmse: 0.1092
# Epoch 238/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0118 - mae: 0.0660 - rmse: 0.0660 - val_loss: 0.0165 - val_mae: 0.1069 - val_rmse: 0.1069
# Epoch 239/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0115 - mae: 0.0652 - rmse: 0.0652 - val_loss: 0.0173 - val_mae: 0.1104 - val_rmse: 0.1104
# Epoch 240/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0115 - mae: 0.0643 - rmse: 0.0643 - val_loss: 0.0181 - val_mae: 0.1136 - val_rmse: 0.1136
# Epoch 241/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0116 - mae: 0.0667 - rmse: 0.0667 - val_loss: 0.0173 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 242/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0112 - mae: 0.0641 - rmse: 0.0641 - val_loss: 0.0153 - val_mae: 0.1027 - val_rmse: 0.1027
# Epoch 243/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0116 - mae: 0.0648 - rmse: 0.0648 - val_loss: 0.0163 - val_mae: 0.1075 - val_rmse: 0.1075
# Epoch 244/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0113 - mae: 0.0644 - rmse: 0.0644 - val_loss: 0.0167 - val_mae: 0.1090 - val_rmse: 0.1090
# Epoch 245/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0111 - mae: 0.0634 - rmse: 0.0634 - val_loss: 0.0168 - val_mae: 0.1093 - val_rmse: 0.1093
# Epoch 246/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0110 - mae: 0.0622 - rmse: 0.0622 - val_loss: 0.0157 - val_mae: 0.1055 - val_rmse: 0.1055
# Epoch 247/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0111 - mae: 0.0644 - rmse: 0.0644 - val_loss: 0.0168 - val_mae: 0.1088 - val_rmse: 0.1088
# Epoch 248/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0109 - mae: 0.0625 - rmse: 0.0625 - val_loss: 0.0183 - val_mae: 0.1136 - val_rmse: 0.1136
# Epoch 249/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0110 - mae: 0.0636 - rmse: 0.0636 - val_loss: 0.0162 - val_mae: 0.1065 - val_rmse: 0.1065
# Epoch 250/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0108 - mae: 0.0638 - rmse: 0.0638 - val_loss: 0.0159 - val_mae: 0.1050 - val_rmse: 0.1050
# Epoch 251/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0110 - mae: 0.0641 - rmse: 0.0641 - val_loss: 0.0158 - val_mae: 0.1040 - val_rmse: 0.1040
# Epoch 252/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0109 - mae: 0.0633 - rmse: 0.0633 - val_loss: 0.0162 - val_mae: 0.1065 - val_rmse: 0.1065
# Epoch 253/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0106 - mae: 0.0628 - rmse: 0.0628 - val_loss: 0.0170 - val_mae: 0.1102 - val_rmse: 0.1102
# Epoch 254/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0112 - mae: 0.0630 - rmse: 0.0630 - val_loss: 0.0170 - val_mae: 0.1089 - val_rmse: 0.1089
# Epoch 255/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0106 - mae: 0.0618 - rmse: 0.0618 - val_loss: 0.0170 - val_mae: 0.1091 - val_rmse: 0.1091
# Epoch 256/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0106 - mae: 0.0618 - rmse: 0.0618 - val_loss: 0.0171 - val_mae: 0.1099 - val_rmse: 0.1099
# Epoch 257/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0107 - mae: 0.0629 - rmse: 0.0629 - val_loss: 0.0157 - val_mae: 0.1043 - val_rmse: 0.1043
# Epoch 258/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0109 - mae: 0.0623 - rmse: 0.0623 - val_loss: 0.0157 - val_mae: 0.1040 - val_rmse: 0.1040
# Epoch 259/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0105 - mae: 0.0626 - rmse: 0.0626 - val_loss: 0.0162 - val_mae: 0.1048 - val_rmse: 0.1048
# Epoch 260/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0102 - mae: 0.0627 - rmse: 0.0627 - val_loss: 0.0185 - val_mae: 0.1149 - val_rmse: 0.1149
# Epoch 261/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0107 - mae: 0.0610 - rmse: 0.0610 - val_loss: 0.0169 - val_mae: 0.1073 - val_rmse: 0.1073
# Epoch 262/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0103 - mae: 0.0621 - rmse: 0.0621 - val_loss: 0.0177 - val_mae: 0.1113 - val_rmse: 0.1113
# Epoch 263/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0104 - mae: 0.0624 - rmse: 0.0624 - val_loss: 0.0153 - val_mae: 0.1021 - val_rmse: 0.1021
# Epoch 264/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0101 - mae: 0.0624 - rmse: 0.0624 - val_loss: 0.0191 - val_mae: 0.1139 - val_rmse: 0.1139
# Epoch 265/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0103 - mae: 0.0631 - rmse: 0.0631 - val_loss: 0.0171 - val_mae: 0.1096 - val_rmse: 0.1096
# Epoch 266/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0101 - mae: 0.0619 - rmse: 0.0619 - val_loss: 0.0152 - val_mae: 0.1013 - val_rmse: 0.1013
# Epoch 267/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0103 - mae: 0.0621 - rmse: 0.0621 - val_loss: 0.0160 - val_mae: 0.1054 - val_rmse: 0.1054
# Epoch 268/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0101 - mae: 0.0594 - rmse: 0.0594 - val_loss: 0.0171 - val_mae: 0.1089 - val_rmse: 0.1089
# Epoch 269/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0101 - mae: 0.0599 - rmse: 0.0599 - val_loss: 0.0155 - val_mae: 0.1034 - val_rmse: 0.1034
# Epoch 270/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0098 - mae: 0.0611 - rmse: 0.0611 - val_loss: 0.0200 - val_mae: 0.1187 - val_rmse: 0.1187
# Epoch 271/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0100 - mae: 0.0614 - rmse: 0.0614 - val_loss: 0.0162 - val_mae: 0.1060 - val_rmse: 0.1060
# Epoch 272/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0101 - mae: 0.0600 - rmse: 0.0600 - val_loss: 0.0159 - val_mae: 0.1031 - val_rmse: 0.1031
# Epoch 273/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0099 - mae: 0.0623 - rmse: 0.0623 - val_loss: 0.0181 - val_mae: 0.1117 - val_rmse: 0.1117
# Epoch 274/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0098 - mae: 0.0602 - rmse: 0.0602 - val_loss: 0.0174 - val_mae: 0.1091 - val_rmse: 0.1091
# Epoch 275/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0101 - mae: 0.0613 - rmse: 0.0613 - val_loss: 0.0170 - val_mae: 0.1084 - val_rmse: 0.1084
# Epoch 276/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0098 - mae: 0.0589 - rmse: 0.0589 - val_loss: 0.0164 - val_mae: 0.1062 - val_rmse: 0.1062
# Epoch 277/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0098 - mae: 0.0606 - rmse: 0.0606 - val_loss: 0.0158 - val_mae: 0.1039 - val_rmse: 0.1039
# Epoch 278/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0097 - mae: 0.0589 - rmse: 0.0589 - val_loss: 0.0153 - val_mae: 0.1019 - val_rmse: 0.1019
# Epoch 279/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0095 - mae: 0.0586 - rmse: 0.0586 - val_loss: 0.0166 - val_mae: 0.1071 - val_rmse: 0.1071
# Epoch 280/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0094 - mae: 0.0586 - rmse: 0.0586 - val_loss: 0.0159 - val_mae: 0.1046 - val_rmse: 0.1046
# Epoch 281/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0096 - mae: 0.0598 - rmse: 0.0598 - val_loss: 0.0168 - val_mae: 0.1037 - val_rmse: 0.1037
# Epoch 282/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0096 - mae: 0.0602 - rmse: 0.0602 - val_loss: 0.0181 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 283/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0092 - mae: 0.0577 - rmse: 0.0577 - val_loss: 0.0198 - val_mae: 0.1140 - val_rmse: 0.1140
# Epoch 284/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0092 - mae: 0.0591 - rmse: 0.0591 - val_loss: 0.0170 - val_mae: 0.1078 - val_rmse: 0.1078
# Epoch 285/700
# ...
# Epoch 607/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mae: 0.0432 - rmse: 0.0432 - val_loss: 0.0162 - val_mae: 0.1059 - val_rmse: 0.1059
# Epoch 608/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0412 - rmse: 0.0412 - val_loss: 0.0157 - val_mae: 0.1043 - val_rmse: 0.1043
# Epoch 609/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0405 - rmse: 0.0405 - val_loss: 0.0175 - val_mae: 0.1120 - val_rmse: 0.1120
# Epoch 610/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0045 - mae: 0.0423 - rmse: 0.0423 - val_loss: 0.0165 - val_mae: 0.1044 - val_rmse: 0.1044
# Epoch 611/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0414 - rmse: 0.0414 - val_loss: 0.0160 - val_mae: 0.1062 - val_rmse: 0.1062
# Epoch 612/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mae: 0.0432 - rmse: 0.0432 - val_loss: 0.0167 - val_mae: 0.1059 - val_rmse: 0.1059
# Epoch 613/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0418 - rmse: 0.0418 - val_loss: 0.0160 - val_mae: 0.1042 - val_rmse: 0.1042
# Epoch 614/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mae: 0.0416 - rmse: 0.0416 - val_loss: 0.0156 - val_mae: 0.1040 - val_rmse: 0.1040
# Epoch 615/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mae: 0.0424 - rmse: 0.0424 - val_loss: 0.0160 - val_mae: 0.1033 - val_rmse: 0.1033
# Epoch 616/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0412 - rmse: 0.0412 - val_loss: 0.0167 - val_mae: 0.1062 - val_rmse: 0.1062
# Epoch 617/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0423 - rmse: 0.0423 - val_loss: 0.0176 - val_mae: 0.1063 - val_rmse: 0.1063
# Epoch 618/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0417 - rmse: 0.0417 - val_loss: 0.0171 - val_mae: 0.1105 - val_rmse: 0.1105
# Epoch 619/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0416 - rmse: 0.0416 - val_loss: 0.0159 - val_mae: 0.1063 - val_rmse: 0.1063
# Epoch 620/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mae: 0.0427 - rmse: 0.0427 - val_loss: 0.0179 - val_mae: 0.1132 - val_rmse: 0.1132
# Epoch 621/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0418 - rmse: 0.0418 - val_loss: 0.0171 - val_mae: 0.1096 - val_rmse: 0.1096
# Epoch 622/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0046 - mae: 0.0435 - rmse: 0.0435 - val_loss: 0.0178 - val_mae: 0.1086 - val_rmse: 0.1086
# Epoch 623/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0423 - rmse: 0.0423 - val_loss: 0.0161 - val_mae: 0.1036 - val_rmse: 0.1036
# Epoch 624/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0045 - mae: 0.0421 - rmse: 0.0421 - val_loss: 0.0169 - val_mae: 0.1052 - val_rmse: 0.1052
# Epoch 625/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mae: 0.0421 - rmse: 0.0421 - val_loss: 0.0162 - val_mae: 0.1041 - val_rmse: 0.1041
# Epoch 626/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mae: 0.0422 - rmse: 0.0422 - val_loss: 0.0158 - val_mae: 0.1052 - val_rmse: 0.1052
# Epoch 627/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0041 - mae: 0.0412 - rmse: 0.0412 - val_loss: 0.0169 - val_mae: 0.1054 - val_rmse: 0.1054
# Epoch 628/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0420 - rmse: 0.0420 - val_loss: 0.0152 - val_mae: 0.1004 - val_rmse: 0.1004
# Epoch 629/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0411 - rmse: 0.0411 - val_loss: 0.0173 - val_mae: 0.1069 - val_rmse: 0.1069
# Epoch 630/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0406 - rmse: 0.0406 - val_loss: 0.0176 - val_mae: 0.1083 - val_rmse: 0.1083
# Epoch 631/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0414 - rmse: 0.0414 - val_loss: 0.0154 - val_mae: 0.1020 - val_rmse: 0.1020
# Epoch 632/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0403 - rmse: 0.0403 - val_loss: 0.0179 - val_mae: 0.1076 - val_rmse: 0.1076
# Epoch 633/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0406 - rmse: 0.0406 - val_loss: 0.0166 - val_mae: 0.1085 - val_rmse: 0.1085
# Epoch 634/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0412 - rmse: 0.0412 - val_loss: 0.0167 - val_mae: 0.1088 - val_rmse: 0.1088
# Epoch 635/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0411 - rmse: 0.0411 - val_loss: 0.0161 - val_mae: 0.1070 - val_rmse: 0.1070
# Epoch 636/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0397 - rmse: 0.0397 - val_loss: 0.0164 - val_mae: 0.1057 - val_rmse: 0.1057
# Epoch 637/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0419 - rmse: 0.0419 - val_loss: 0.0180 - val_mae: 0.1107 - val_rmse: 0.1107
# Epoch 638/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0402 - rmse: 0.0402 - val_loss: 0.0165 - val_mae: 0.1097 - val_rmse: 0.1097
# Epoch 639/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0404 - rmse: 0.0404 - val_loss: 0.0171 - val_mae: 0.1074 - val_rmse: 0.1074
# Epoch 640/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0411 - rmse: 0.0411 - val_loss: 0.0172 - val_mae: 0.1080 - val_rmse: 0.1080
# Epoch 641/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0405 - rmse: 0.0405 - val_loss: 0.0157 - val_mae: 0.1033 - val_rmse: 0.1033
# Epoch 642/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0395 - rmse: 0.0395 - val_loss: 0.0158 - val_mae: 0.1040 - val_rmse: 0.1040
# Epoch 643/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0409 - rmse: 0.0409 - val_loss: 0.0165 - val_mae: 0.1088 - val_rmse: 0.1088
# Epoch 644/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0404 - rmse: 0.0404 - val_loss: 0.0210 - val_mae: 0.1153 - val_rmse: 0.1153
# Epoch 645/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mae: 0.0430 - rmse: 0.0430 - val_loss: 0.0179 - val_mae: 0.1107 - val_rmse: 0.1107
# Epoch 646/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0410 - rmse: 0.0410 - val_loss: 0.0169 - val_mae: 0.1107 - val_rmse: 0.1107
# Epoch 647/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0414 - rmse: 0.0414 - val_loss: 0.0166 - val_mae: 0.1071 - val_rmse: 0.1071
# Epoch 648/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0439 - rmse: 0.0439 - val_loss: 0.0159 - val_mae: 0.1055 - val_rmse: 0.1055
# Epoch 649/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0040 - mae: 0.0404 - rmse: 0.0404 - val_loss: 0.0197 - val_mae: 0.1135 - val_rmse: 0.1135
# Epoch 650/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0407 - rmse: 0.0407 - val_loss: 0.0176 - val_mae: 0.1099 - val_rmse: 0.1099
# Epoch 651/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0039 - mae: 0.0410 - rmse: 0.0410 - val_loss: 0.0165 - val_mae: 0.1084 - val_rmse: 0.1084
# Epoch 652/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0418 - rmse: 0.0418 - val_loss: 0.0178 - val_mae: 0.1124 - val_rmse: 0.1124
# Epoch 653/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0417 - rmse: 0.0417 - val_loss: 0.0174 - val_mae: 0.1087 - val_rmse: 0.1087
# Epoch 654/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0408 - rmse: 0.0408 - val_loss: 0.0177 - val_mae: 0.1091 - val_rmse: 0.1091
# Epoch 655/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0421 - rmse: 0.0421 - val_loss: 0.0165 - val_mae: 0.1062 - val_rmse: 0.1062
# Epoch 656/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0414 - rmse: 0.0414 - val_loss: 0.0158 - val_mae: 0.1042 - val_rmse: 0.1042
# Epoch 657/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0406 - rmse: 0.0406 - val_loss: 0.0164 - val_mae: 0.1066 - val_rmse: 0.1066
# Epoch 658/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0424 - rmse: 0.0424 - val_loss: 0.0171 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 659/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0407 - rmse: 0.0407 - val_loss: 0.0173 - val_mae: 0.1080 - val_rmse: 0.1080
# Epoch 660/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0043 - mae: 0.0423 - rmse: 0.0423 - val_loss: 0.0166 - val_mae: 0.1069 - val_rmse: 0.1069
# Epoch 661/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0396 - rmse: 0.0396 - val_loss: 0.0172 - val_mae: 0.1118 - val_rmse: 0.1118
# Epoch 662/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0416 - rmse: 0.0416 - val_loss: 0.0173 - val_mae: 0.1082 - val_rmse: 0.1082
# Epoch 663/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0406 - rmse: 0.0406 - val_loss: 0.0176 - val_mae: 0.1096 - val_rmse: 0.1096
# Epoch 664/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0413 - rmse: 0.0413 - val_loss: 0.0168 - val_mae: 0.1107 - val_rmse: 0.1107
# Epoch 665/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0418 - rmse: 0.0418 - val_loss: 0.0168 - val_mae: 0.1081 - val_rmse: 0.1081
# Epoch 666/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0408 - rmse: 0.0408 - val_loss: 0.0168 - val_mae: 0.1079 - val_rmse: 0.1079
# Epoch 667/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0414 - rmse: 0.0414 - val_loss: 0.0172 - val_mae: 0.1090 - val_rmse: 0.1090
# Epoch 668/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0394 - rmse: 0.0394 - val_loss: 0.0177 - val_mae: 0.1105 - val_rmse: 0.1105
# Epoch 669/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0422 - rmse: 0.0422 - val_loss: 0.0159 - val_mae: 0.1040 - val_rmse: 0.1040
# Epoch 670/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0395 - rmse: 0.0395 - val_loss: 0.0162 - val_mae: 0.1042 - val_rmse: 0.1042
# Epoch 671/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0410 - rmse: 0.0410 - val_loss: 0.0160 - val_mae: 0.1054 - val_rmse: 0.1054
# Epoch 672/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0411 - rmse: 0.0411 - val_loss: 0.0168 - val_mae: 0.1081 - val_rmse: 0.1081
# Epoch 673/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0394 - rmse: 0.0394 - val_loss: 0.0164 - val_mae: 0.1067 - val_rmse: 0.1067
# Epoch 674/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0039 - mae: 0.0400 - rmse: 0.0400 - val_loss: 0.0182 - val_mae: 0.1178 - val_rmse: 0.1178
# Epoch 675/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0416 - rmse: 0.0416 - val_loss: 0.0176 - val_mae: 0.1143 - val_rmse: 0.1143
# Epoch 676/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0406 - rmse: 0.0406 - val_loss: 0.0178 - val_mae: 0.1101 - val_rmse: 0.1101
# Epoch 677/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0040 - mae: 0.0406 - rmse: 0.0406 - val_loss: 0.0169 - val_mae: 0.1107 - val_rmse: 0.1107
# Epoch 678/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0036 - mae: 0.0396 - rmse: 0.0396 - val_loss: 0.0216 - val_mae: 0.1155 - val_rmse: 0.1155
# Epoch 679/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0426 - rmse: 0.0426 - val_loss: 0.0168 - val_mae: 0.1082 - val_rmse: 0.1082
# Epoch 680/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0409 - rmse: 0.0409 - val_loss: 0.0199 - val_mae: 0.1115 - val_rmse: 0.1115
# Epoch 681/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0408 - rmse: 0.0408 - val_loss: 0.0162 - val_mae: 0.1080 - val_rmse: 0.1080
# Epoch 682/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0409 - rmse: 0.0409 - val_loss: 0.0169 - val_mae: 0.1103 - val_rmse: 0.1103
# Epoch 683/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mae: 0.0414 - rmse: 0.0414 - val_loss: 0.0161 - val_mae: 0.1074 - val_rmse: 0.1074
# Epoch 684/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0403 - rmse: 0.0403 - val_loss: 0.0177 - val_mae: 0.1095 - val_rmse: 0.1095
# Epoch 685/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0038 - mae: 0.0402 - rmse: 0.0402 - val_loss: 0.0158 - val_mae: 0.1042 - val_rmse: 0.1042
# Epoch 686/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0403 - rmse: 0.0403 - val_loss: 0.0162 - val_mae: 0.1045 - val_rmse: 0.1045
# Epoch 687/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0409 - rmse: 0.0409 - val_loss: 0.0169 - val_mae: 0.1108 - val_rmse: 0.1108
# Epoch 688/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0402 - rmse: 0.0402 - val_loss: 0.0170 - val_mae: 0.1093 - val_rmse: 0.1093
# Epoch 689/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0039 - mae: 0.0394 - rmse: 0.0394 - val_loss: 0.0164 - val_mae: 0.1081 - val_rmse: 0.1081
# Epoch 690/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0396 - rmse: 0.0396 - val_loss: 0.0166 - val_mae: 0.1099 - val_rmse: 0.1099
# Epoch 691/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0411 - rmse: 0.0411 - val_loss: 0.0168 - val_mae: 0.1075 - val_rmse: 0.1075
# Epoch 692/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0039 - mae: 0.0397 - rmse: 0.0397 - val_loss: 0.0163 - val_mae: 0.1064 - val_rmse: 0.1064
# Epoch 693/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0041 - mae: 0.0415 - rmse: 0.0415 - val_loss: 0.0164 - val_mae: 0.1060 - val_rmse: 0.1060
# Epoch 694/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0039 - mae: 0.0391 - rmse: 0.0391 - val_loss: 0.0176 - val_mae: 0.1134 - val_rmse: 0.1134
# Epoch 695/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0040 - mae: 0.0409 - rmse: 0.0409 - val_loss: 0.0168 - val_mae: 0.1086 - val_rmse: 0.1086
# Epoch 696/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0039 - mae: 0.0397 - rmse: 0.0397 - val_loss: 0.0173 - val_mae: 0.1084 - val_rmse: 0.1084
# Epoch 697/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0039 - mae: 0.0392 - rmse: 0.0392 - val_loss: 0.0191 - val_mae: 0.1132 - val_rmse: 0.1132
# Epoch 698/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0038 - mae: 0.0399 - rmse: 0.0399 - val_loss: 0.0220 - val_mae: 0.1199 - val_rmse: 0.1199
# Epoch 699/700
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mae: 0.0400 - rmse: 0.0400 - val_loss: 0.0164 - val_mae: 0.1077 - val_rmse: 0.1077
# Epoch 700/700
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0038 - mae: 0.0397 - rmse: 0.0397 - val_loss: 0.0168 - val_mae: 0.1119 - val_rmse: 0.1119
# 学習時間: 602.1799855232239

# %%
# model.save('covid19_gru_model.h5')
# files.download('covid19_gru_model.h5')

# %%
# === 学習推移の可視化 ===
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(np.arange(len(train_loss)), train_loss, label="train_loss")
plt.plot(np.arange(len(val_loss)), val_loss, label="val_loss")
plt.title('Training and Validation loss')
plt.ylim((0, 0.04))#add
plt.legend()
plt.show()

train_mae = history.history['mae']
val_mae = history.history['val_mae']

plt.plot(np.arange(len(train_mae)), train_mae, label="train_mae")
plt.plot(np.arange(len(val_mae)), val_mae, label="val_mae")
plt.title('Training and Validation mae')
plt.ylim((0, 0.2))#add
plt.legend()
plt.show()

train_rmse = history.history['rmse']
val_rmse = history.history['val_rmse']

plt.plot(np.arange(len(train_loss)), train_rmse, label="train_rmse")
plt.plot(np.arange(len(val_loss)), val_rmse, label="val_rmse")
plt.title('Training and Validation rmse')
plt.ylim((0, 0.2))#add
plt.legend()
plt.show()

# %%
#training predictions
predicted_past_data = model.predict(study_data)
train_inverse= scaler.inverse_transform(predicted_past_data)

#test predictions
upcoming_future=7
predictions = train_normalized[-window:].tolist()
predictions = np.array(predictions).reshape(-1, window, 1)
#予測をfor文で
for i in range(upcoming_future):
  predicted_future = model.predict(predictions)
  with open("in_out.txt",mode="a", encoding= "utf-8") as f:
    f.write("input to model:" + str(predictions) )
    f.write("output from model:" + str(predicted_future) )
  #predictions = predictions.tolist()
  predictions = np.append(predictions,predicted_future)
  predictions = predictions[-window:]
  predictions = np.array(predictions).reshape(-1, window, 1)

predictions_infected_pepole = scaler.inverse_transform(np.array(predictions).reshape(-1,1))
#print(predictions_infected_pepole)

x_all =np.arange('2020-01-23','2020-10-29', dtype='datetime64[D]').astype('datetime64[D]')
x_past_predict = np.arange('2020-01-30','2020-10-22', dtype='datetime64[D]').astype('datetime64[D]')#23-26
x_train = np.arange('2020-01-23','2020-10-22', dtype='datetime64[D]').astype('datetime64[D]')
x_test = np.arange('2020-10-22', '2020-10-29', dtype='datetime64[D]').astype('datetime64[D]')

sns.set()
COVID = plt.figure(figsize=(20,8))
plt.title("COVID-19 in Japan")
plt.grid(True)
plt.xlabel("Day")
plt.ylabel("Nunber of Person infected with corona virus")
plt.plot(x_all,data_at_japan_diff,'g',lw=3,label='daily_at_japan')
#plt.plot(x_train,train_original_data,label='train_data')
#plt.plot(x_test,test_original_data,label='test_data')
plt.plot(x_past_predict,train_inverse,color='b', ls='-',lw=3,alpha=0.7, label='past_predict')#+8かも
plt.plot(x_test, predictions_infected_pepole, 'r',lw=3,alpha=0.7,label='upcoming_future')
plt.legend(loc='upper left')
plt.show()

sns.set()
COVID = plt.figure(figsize=(20,8))
plt.title("COVID-19 in Japan")
plt.grid(True)
plt.xlabel("Day")
plt.ylabel("Nunber of Person infected with corona virus")
plt.plot(x_test,test_original_data,color='b', ls='-',lw=3,alpha=0.7, label='past_predict')
plt.plot(x_test, predictions_infected_pepole, 'r',lw=3,alpha=0.7,label='upcoming_future')
plt.show()

# %%
train_data = train_original_data[7:]
train_mae = mean_absolute_error(train_data, train_inverse)
train_mse = mean_squared_error(train_data, train_inverse)
train_rmse = np.sqrt(mean_squared_error(train_data, train_inverse))
train_r2 = r2_score(train_data, train_inverse)

test_mae = mean_absolute_error(test_original_data, predictions_infected_pepole)
test_mse = mean_squared_error(test_original_data, predictions_infected_pepole)
test_rmse = np.sqrt(mean_squared_error(test_original_data, predictions_infected_pepole))
test_r2 = r2_score(test_original_data, predictions_infected_pepole)

print('train_mae:'+str(train_mae))
print('train_mse:'+str(train_mse))
print('train_rmae:'+str(train_rmse))
print('train_r2:'+str(train_r2))
print('')
print('test_mae:'+str(test_mae))
print('test_mae:'+str(test_mse))
print('test_mae:'+str(test_rmse))
print('test_mae:'+str(test_r2))#r2 最も当てはまりの良い場合、1.0 となります (当てはまりの悪い場合、マイナスとなることもあります)
# Out:
# train_mae:39.84915057160801
# train_mse:3913.8364483567316
# train_rmae:62.56066214768456
# train_r2:0.9722936954262534
#
# test_mae:108.06979128292629
# test_mae:19975.39918091789
# test_mae:141.33435244454157
# test_mae:-0.42074190176240456

# %%
#long term predictions
x_long_term = np.arange('2020-10-22', '2020-11-21', dtype='datetime64[D]').astype('datetime64[D]')#11-21
long_term_future = len(x_long_term)
print(str(long_term_future) + '日間後')

predictions2 = train_normalized[-window:].tolist()
predictions2 = np.array(predictions2).reshape(-1, window, 1)

long_term_predictions = []
#予測をfor文で
for i in range(long_term_future):
  predicted_long_term_future = model.predict(predictions2)
  long_term_predictions.append(predicted_long_term_future)
  # with open("in_out_long_term.txt",mode="a", encoding= "utf-8") as f:
  #   f.write("input to model:" + str(predictions) )
  #   f.write("output from model:" + str(predicted_future) )
  #predictions2 = predictions2.tolist()
  predictions2 = np.append(predictions2, predicted_long_term_future)
  predictions2 = predictions2[-window:]
  predictions2 = np.array(predictions2).reshape(-1, window, 1)

predictions_infected_pepole_long_term = scaler.inverse_transform(np.array(long_term_predictions).reshape(-1,1))
#print(predictions_infected_pepole_long_term)


sns.set()
COVID = plt.figure(figsize=(20,8))
plt.title("COVID-19 in Japan after" + str(long_term_future) + 'days')
plt.grid(True)
plt.xlabel("Day(/Day)")
plt.ylabel("Nunber of Person infected with corona virus(/people)")
plt.plot(x_all,data_at_japan_diff,'g',lw=3,label='daily_at_japan')
plt.plot(x_long_term, predictions_infected_pepole_long_term, 'r',lw=3,alpha=0.7,label='upcoming_future')
plt.legend(loc='upper left')
plt.show()
# Out:
# 30日間後
