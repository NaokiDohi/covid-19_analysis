# %% [markdown]
# <a href="https://colab.research.google.com/github/NaokiDohi/covid-19_analysis/blob/master/covid_19_forecast_with_gru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime as dt#デフォはUTCの国際基準時間
import pytz#日本時間に変換
import time

import numpy as np
import pandas as pd
from pandas.plotting import register_matplotlib_converters
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

import statsmodels.api as sm # version 0.8.0以上
from sklearn.preprocessing import  MinMaxScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,r2_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout,GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from keras import regularizers
from keras.models import load_model
from keras import backend as K

from google.colab import files
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
path = 'COVID-19'
if not os.path.exists(path):
  # !git clone https://github.com/CSSEGISandData/COVID-19.git
else:
  print("Dude!! This file is already download")
#dataの更新は21：３０に行われる？
# Out:
# Cloning into 'COVID-19'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 60562 (delta 8), reused 14 (delta 7), pack-reused 60544
# Receiving objects: 100% (60562/60562), 515.17 MiB | 34.79 MiB/s, done.
# Resolving deltas: 100% (38474/38474), done.
# Checking out files: 100% (710/710), done.

# %%
df = pd.read_csv('COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df = df[df['Country/Region']=='Japan']
df
# Out:
#     Province/State Country/Region        Lat  ...  10/26/20  10/27/20  10/28/20
# 151            NaN          Japan  36.204824  ...     97503     98146     98877
#
# [1 rows x 285 columns]

# %%
df = df.iloc[:,4:].copy()
data_at_japan = df.iloc[0,:]
data_at_japan.index = pd.to_datetime(data_at_japan.index)
print(data_at_japan)
# Out:
# 2020-01-22        2
# 2020-01-23        2
# 2020-01-24        2
# 2020-01-25        2
# 2020-01-26        4
#               ...
# 2020-10-24    96599
# 2020-10-25    97095
# 2020-10-26    97503
# 2020-10-27    98146
# 2020-10-28    98877
# Name: 151, Length: 281, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.plot(data_at_japan)
plt.title("Japan COVID-19")
plt.xlabel("Date")
plt.ylabel("Person infected")
plt.grid(True)
plt.show()

# %%
data_at_japan_diff = data_at_japan - data_at_japan.shift(1) # 階差系列データの作成
data_at_japan_diff = data_at_japan_diff.dropna()
data_at_japan_diff
# Out:
# 2020-01-23      0.0
# 2020-01-24      0.0
# 2020-01-25      0.0
# 2020-01-26      2.0
# 2020-01-27      0.0
#               ...
# 2020-10-24    731.0
# 2020-10-25    496.0
# 2020-10-26    408.0
# 2020-10-27    643.0
# 2020-10-28    731.0
# Name: 151, Length: 280, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.plot(data_at_japan_diff)
plt.title('COVID-19 confilmed at Japan')
plt.xlabel('Date')
plt.ylabel('Person infected')
plt.grid()
plt.show()

# %%
hoge=data_at_japan_diff[-31:]
#print(hoge)
plt.figure(figsize=(18,8))
plt.plot(hoge)
plt.grid()
plt.show()

# %%
res = sm.tsa.seasonal_decompose(data_at_japan_diff)#データを分解

original = data_at_japan_diff # オリジナルデータ
trend_original = res.trend # トレンドデータ
seasonal_original = res.seasonal # 季節性データ
residual = res.resid # 残差データ

plt.figure(figsize=(8, 8)) # グラフ描画枠作成、サイズ指定

# オリジナルデータのプロット
plt.subplot(411) # グラフ4行1列の1番目の位置（一番上）
plt.plot(original)
plt.ylabel('Original')

# trend データのプロット
plt.subplot(412) # グラフ4行1列の2番目の位置
plt.plot(trend_original)
plt.ylabel('Trend')

# seasonalデータ のプロット
plt.subplot(413) # グラフ4行1列の3番目の位置
plt.plot(seasonal_original)
plt.ylabel('Seasonality')

# residual データのプロット
plt.subplot(414) # グラフ4行1列の4番目の位置（一番下）
plt.plot(residual)
plt.ylabel('Residuals')

plt.tight_layout() # グラフの間隔を自動調整

# %%
y = data_at_japan_diff.values.astype(float)
len(y)
# Out:
# 280

# %%
test_size = 7
train_original_data = y[:-test_size]#0から後ろから4個目までを取り出す。　つまり学習用のデータ(学習の範囲)は直近３日間前
test_original_data = y[-test_size:]#最後から３つを取り出す。　検証用データは直近３日間前

# %%
def sequence_creator(input_data,window_size):#train_normalizedとwindow_sizeを渡し訓練データと正解ラベルを返す

    data, target = [], []
    data_len = len(input_data)
    for i in range(data_len - window_size):#data_lenのままだとwindowが配列を超えてしまう
        window_fr = input_data[i:i+window_size]#iを始点にwindow数取り出す
        correct_label = input_data[i+window_size:i+window_size+1]#index番号がi+windowの値を取り出す。つまりwindowの後にある正解ラベルを取り出す。
        data.append(window_fr)
        target.append(correct_label)

    re_data = np.array(data).reshape(len(data), window_size, 1)#kerasのRNNでは入力をサンプル数,時系列数(window数),入力層のニューロン数にする。　本来なら−１でなくlen(data)?
    re_target = np.array(target).reshape(len(target), 1)#入力と同じにする必要がある。

    return re_data, re_target

# %%
scaler = MinMaxScaler(feature_range=(-1,1))#feature_rangeは引数に正規化変換後の最大値と最小値を決める。今回は−１から１で正規化
train_normalized = scaler.fit_transform(train_original_data.reshape(-1,1))#学習用データに正規化の適用　またskleranの入力形状に適用 合わせた行と１列

# %%
window = 7#学習時のウィンドウサイズ

# %%
study_data, correct_data  = sequence_creator(train_normalized, window)

# %%
n_in_out = 1
n_hidden = 8#2の乗数 128#256 #512

def rmse(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

model = Sequential()
model.add(GRU(n_hidden, batch_input_shape=(None, window, n_in_out), return_sequences=False,))#activation='relu',kernel_initializer='he_normal'))
#,kernel_regularizer=regularizers.l1(0.01)
#model.add(Dropout(0.2))
model.add(Dense(n_in_out))
model.add(Activation("linear"))
optimizer = Adam(lr=0.001,  amsgrad=True)
model.compile(loss="mse", optimizer=optimizer,metrics=["mae",rmse])# optimizer="rmsprop"
print(model.summary())
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_21 (GRU)                 (None, 8)                 264
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 9
# _________________________________________________________________
# activation_21 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=1)
# 学習率を返す関数を用意する
def lr_schedul(epoch):
    x = 0.001
    if epoch >= 300:
        x = 0.0005
    return x


lr_decay = LearningRateScheduler(
    lr_schedul,
    # verbose=1で、更新メッセージ表示。0の場合は表示しない
    verbose=0,
)

epochs = 500
start_time = time.time()
history = model.fit(study_data, correct_data, batch_size=1, epochs=epochs, validation_split=0.1, verbose=1, callbacks=[])#lr_decay,
print("学習時間:",time.time() - start_time)
# Out:
# Epoch 1/500
# 239/239 [==============================] - 1s 5ms/step - loss: 0.1216 - mae: 0.2443 - rmse: 0.2443 - val_loss: 0.0314 - val_mae: 0.1571 - val_rmse: 0.1571
# Epoch 2/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0313 - mae: 0.1130 - rmse: 0.1130 - val_loss: 0.0284 - val_mae: 0.1426 - val_rmse: 0.1426
# Epoch 3/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0271 - mae: 0.0996 - rmse: 0.0996 - val_loss: 0.0285 - val_mae: 0.1438 - val_rmse: 0.1438
# Epoch 4/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0266 - mae: 0.1011 - rmse: 0.1011 - val_loss: 0.0273 - val_mae: 0.1319 - val_rmse: 0.1319
# Epoch 5/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0256 - mae: 0.0954 - rmse: 0.0954 - val_loss: 0.0268 - val_mae: 0.1310 - val_rmse: 0.1310
# Epoch 6/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0252 - mae: 0.0959 - rmse: 0.0959 - val_loss: 0.0269 - val_mae: 0.1283 - val_rmse: 0.1283
# Epoch 7/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0248 - mae: 0.0968 - rmse: 0.0968 - val_loss: 0.0269 - val_mae: 0.1316 - val_rmse: 0.1316
# Epoch 8/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0242 - mae: 0.0928 - rmse: 0.0928 - val_loss: 0.0274 - val_mae: 0.1417 - val_rmse: 0.1417
# Epoch 9/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0245 - mae: 0.0920 - rmse: 0.0920 - val_loss: 0.0261 - val_mae: 0.1372 - val_rmse: 0.1372
# Epoch 10/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0238 - mae: 0.0920 - rmse: 0.0920 - val_loss: 0.0262 - val_mae: 0.1380 - val_rmse: 0.1380
# Epoch 11/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0237 - mae: 0.0934 - rmse: 0.0934 - val_loss: 0.0260 - val_mae: 0.1414 - val_rmse: 0.1414
# Epoch 12/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0235 - mae: 0.0940 - rmse: 0.0940 - val_loss: 0.0252 - val_mae: 0.1342 - val_rmse: 0.1342
# Epoch 13/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0231 - mae: 0.0897 - rmse: 0.0897 - val_loss: 0.0250 - val_mae: 0.1310 - val_rmse: 0.1310
# Epoch 14/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0233 - mae: 0.0931 - rmse: 0.0931 - val_loss: 0.0250 - val_mae: 0.1354 - val_rmse: 0.1354
# Epoch 15/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0228 - mae: 0.0895 - rmse: 0.0895 - val_loss: 0.0249 - val_mae: 0.1356 - val_rmse: 0.1356
# Epoch 16/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0229 - mae: 0.0927 - rmse: 0.0927 - val_loss: 0.0255 - val_mae: 0.1427 - val_rmse: 0.1427
# Epoch 17/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0223 - mae: 0.0909 - rmse: 0.0909 - val_loss: 0.0248 - val_mae: 0.1389 - val_rmse: 0.1389
# Epoch 18/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0226 - mae: 0.0916 - rmse: 0.0916 - val_loss: 0.0242 - val_mae: 0.1351 - val_rmse: 0.1351
# Epoch 19/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0219 - mae: 0.0875 - rmse: 0.0875 - val_loss: 0.0243 - val_mae: 0.1397 - val_rmse: 0.1397
# Epoch 20/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0224 - mae: 0.0892 - rmse: 0.0892 - val_loss: 0.0238 - val_mae: 0.1303 - val_rmse: 0.1303
# Epoch 21/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0219 - mae: 0.0901 - rmse: 0.0901 - val_loss: 0.0232 - val_mae: 0.1305 - val_rmse: 0.1305
# Epoch 22/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0219 - mae: 0.0922 - rmse: 0.0922 - val_loss: 0.0237 - val_mae: 0.1301 - val_rmse: 0.1301
# Epoch 23/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0213 - mae: 0.0879 - rmse: 0.0879 - val_loss: 0.0230 - val_mae: 0.1257 - val_rmse: 0.1257
# Epoch 24/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0215 - mae: 0.0912 - rmse: 0.0912 - val_loss: 0.0236 - val_mae: 0.1319 - val_rmse: 0.1319
# Epoch 25/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0215 - mae: 0.0896 - rmse: 0.0896 - val_loss: 0.0230 - val_mae: 0.1253 - val_rmse: 0.1253
# Epoch 26/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0217 - mae: 0.0903 - rmse: 0.0903 - val_loss: 0.0229 - val_mae: 0.1329 - val_rmse: 0.1329
# Epoch 27/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0216 - mae: 0.0887 - rmse: 0.0887 - val_loss: 0.0223 - val_mae: 0.1275 - val_rmse: 0.1275
# Epoch 28/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0215 - mae: 0.0895 - rmse: 0.0895 - val_loss: 0.0224 - val_mae: 0.1319 - val_rmse: 0.1319
# Epoch 29/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0208 - mae: 0.0886 - rmse: 0.0886 - val_loss: 0.0235 - val_mae: 0.1255 - val_rmse: 0.1255
# Epoch 30/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0215 - mae: 0.0891 - rmse: 0.0891 - val_loss: 0.0226 - val_mae: 0.1266 - val_rmse: 0.1266
# Epoch 31/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0209 - mae: 0.0897 - rmse: 0.0897 - val_loss: 0.0226 - val_mae: 0.1228 - val_rmse: 0.1228
# Epoch 32/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0209 - mae: 0.0878 - rmse: 0.0878 - val_loss: 0.0219 - val_mae: 0.1265 - val_rmse: 0.1265
# Epoch 33/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0213 - mae: 0.0879 - rmse: 0.0879 - val_loss: 0.0222 - val_mae: 0.1275 - val_rmse: 0.1275
# Epoch 34/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0208 - mae: 0.0886 - rmse: 0.0886 - val_loss: 0.0214 - val_mae: 0.1238 - val_rmse: 0.1238
# Epoch 35/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0210 - mae: 0.0873 - rmse: 0.0873 - val_loss: 0.0215 - val_mae: 0.1287 - val_rmse: 0.1287
# Epoch 36/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0210 - mae: 0.0880 - rmse: 0.0880 - val_loss: 0.0217 - val_mae: 0.1296 - val_rmse: 0.1296
# Epoch 37/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0207 - mae: 0.0890 - rmse: 0.0890 - val_loss: 0.0213 - val_mae: 0.1256 - val_rmse: 0.1256
# Epoch 38/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0210 - mae: 0.0892 - rmse: 0.0892 - val_loss: 0.0216 - val_mae: 0.1230 - val_rmse: 0.1230
# Epoch 39/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0210 - mae: 0.0893 - rmse: 0.0893 - val_loss: 0.0210 - val_mae: 0.1245 - val_rmse: 0.1245
# Epoch 40/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0208 - mae: 0.0915 - rmse: 0.0915 - val_loss: 0.0222 - val_mae: 0.1342 - val_rmse: 0.1342
# Epoch 41/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0210 - mae: 0.0899 - rmse: 0.0899 - val_loss: 0.0216 - val_mae: 0.1294 - val_rmse: 0.1294
# Epoch 42/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0206 - mae: 0.0881 - rmse: 0.0881 - val_loss: 0.0211 - val_mae: 0.1216 - val_rmse: 0.1216
# Epoch 43/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0208 - mae: 0.0875 - rmse: 0.0875 - val_loss: 0.0207 - val_mae: 0.1244 - val_rmse: 0.1244
# Epoch 44/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0205 - mae: 0.0861 - rmse: 0.0861 - val_loss: 0.0214 - val_mae: 0.1303 - val_rmse: 0.1303
# Epoch 45/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0868 - rmse: 0.0868 - val_loss: 0.0212 - val_mae: 0.1229 - val_rmse: 0.1229
# Epoch 46/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0206 - mae: 0.0867 - rmse: 0.0867 - val_loss: 0.0208 - val_mae: 0.1216 - val_rmse: 0.1216
# Epoch 47/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0863 - rmse: 0.0863 - val_loss: 0.0209 - val_mae: 0.1217 - val_rmse: 0.1217
# Epoch 48/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0205 - mae: 0.0864 - rmse: 0.0864 - val_loss: 0.0206 - val_mae: 0.1256 - val_rmse: 0.1256
# Epoch 49/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0865 - rmse: 0.0865 - val_loss: 0.0199 - val_mae: 0.1216 - val_rmse: 0.1216
# Epoch 50/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0203 - mae: 0.0867 - rmse: 0.0867 - val_loss: 0.0202 - val_mae: 0.1215 - val_rmse: 0.1215
# Epoch 51/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0854 - rmse: 0.0854 - val_loss: 0.0202 - val_mae: 0.1209 - val_rmse: 0.1209
# Epoch 52/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0203 - mae: 0.0875 - rmse: 0.0875 - val_loss: 0.0203 - val_mae: 0.1227 - val_rmse: 0.1227
# Epoch 53/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0203 - mae: 0.0859 - rmse: 0.0859 - val_loss: 0.0202 - val_mae: 0.1224 - val_rmse: 0.1224
# Epoch 54/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0860 - rmse: 0.0860 - val_loss: 0.0197 - val_mae: 0.1219 - val_rmse: 0.1219
# Epoch 55/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0203 - mae: 0.0867 - rmse: 0.0867 - val_loss: 0.0198 - val_mae: 0.1215 - val_rmse: 0.1215
# Epoch 56/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0865 - rmse: 0.0865 - val_loss: 0.0197 - val_mae: 0.1190 - val_rmse: 0.1190
# Epoch 57/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0200 - mae: 0.0877 - rmse: 0.0877 - val_loss: 0.0200 - val_mae: 0.1197 - val_rmse: 0.1197
# Epoch 58/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0198 - mae: 0.0868 - rmse: 0.0868 - val_loss: 0.0198 - val_mae: 0.1207 - val_rmse: 0.1207
# Epoch 59/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0201 - mae: 0.0868 - rmse: 0.0868 - val_loss: 0.0196 - val_mae: 0.1238 - val_rmse: 0.1238
# Epoch 60/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0834 - rmse: 0.0834 - val_loss: 0.0208 - val_mae: 0.1293 - val_rmse: 0.1293
# Epoch 61/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0201 - mae: 0.0847 - rmse: 0.0847 - val_loss: 0.0190 - val_mae: 0.1195 - val_rmse: 0.1195
# Epoch 62/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0202 - mae: 0.0879 - rmse: 0.0879 - val_loss: 0.0191 - val_mae: 0.1211 - val_rmse: 0.1211
# Epoch 63/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0200 - mae: 0.0887 - rmse: 0.0887 - val_loss: 0.0194 - val_mae: 0.1240 - val_rmse: 0.1240
# Epoch 64/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0853 - rmse: 0.0853 - val_loss: 0.0202 - val_mae: 0.1272 - val_rmse: 0.1272
# Epoch 65/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0200 - mae: 0.0869 - rmse: 0.0869 - val_loss: 0.0189 - val_mae: 0.1206 - val_rmse: 0.1206
# Epoch 66/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0198 - mae: 0.0847 - rmse: 0.0847 - val_loss: 0.0191 - val_mae: 0.1205 - val_rmse: 0.1205
# Epoch 67/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0868 - rmse: 0.0868 - val_loss: 0.0188 - val_mae: 0.1201 - val_rmse: 0.1201
# Epoch 68/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0198 - mae: 0.0876 - rmse: 0.0876 - val_loss: 0.0188 - val_mae: 0.1197 - val_rmse: 0.1197
# Epoch 69/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0852 - rmse: 0.0852 - val_loss: 0.0189 - val_mae: 0.1208 - val_rmse: 0.1208
# Epoch 70/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0197 - mae: 0.0857 - rmse: 0.0857 - val_loss: 0.0194 - val_mae: 0.1241 - val_rmse: 0.1241
# Epoch 71/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0198 - mae: 0.0868 - rmse: 0.0868 - val_loss: 0.0184 - val_mae: 0.1184 - val_rmse: 0.1184
# Epoch 72/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0199 - mae: 0.0870 - rmse: 0.0870 - val_loss: 0.0187 - val_mae: 0.1197 - val_rmse: 0.1197
# Epoch 73/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0850 - rmse: 0.0850 - val_loss: 0.0188 - val_mae: 0.1198 - val_rmse: 0.1198
# Epoch 74/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0197 - mae: 0.0848 - rmse: 0.0848 - val_loss: 0.0185 - val_mae: 0.1196 - val_rmse: 0.1196
# Epoch 75/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0198 - mae: 0.0875 - rmse: 0.0875 - val_loss: 0.0187 - val_mae: 0.1203 - val_rmse: 0.1203
# Epoch 76/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0854 - rmse: 0.0854 - val_loss: 0.0185 - val_mae: 0.1191 - val_rmse: 0.1191
# Epoch 77/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0867 - rmse: 0.0867 - val_loss: 0.0188 - val_mae: 0.1180 - val_rmse: 0.1180
# Epoch 78/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0198 - mae: 0.0846 - rmse: 0.0846 - val_loss: 0.0190 - val_mae: 0.1196 - val_rmse: 0.1196
# Epoch 79/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0196 - mae: 0.0858 - rmse: 0.0858 - val_loss: 0.0189 - val_mae: 0.1215 - val_rmse: 0.1215
# Epoch 80/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0191 - mae: 0.0850 - rmse: 0.0850 - val_loss: 0.0194 - val_mae: 0.1242 - val_rmse: 0.1242
# Epoch 81/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0837 - rmse: 0.0837 - val_loss: 0.0186 - val_mae: 0.1196 - val_rmse: 0.1196
# Epoch 82/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0192 - mae: 0.0849 - rmse: 0.0849 - val_loss: 0.0192 - val_mae: 0.1231 - val_rmse: 0.1231
# Epoch 83/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0192 - mae: 0.0854 - rmse: 0.0854 - val_loss: 0.0187 - val_mae: 0.1175 - val_rmse: 0.1175
# Epoch 84/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0190 - mae: 0.0823 - rmse: 0.0823 - val_loss: 0.0186 - val_mae: 0.1185 - val_rmse: 0.1185
# Epoch 85/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0862 - rmse: 0.0862 - val_loss: 0.0186 - val_mae: 0.1197 - val_rmse: 0.1197
# Epoch 86/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0191 - mae: 0.0864 - rmse: 0.0864 - val_loss: 0.0192 - val_mae: 0.1234 - val_rmse: 0.1234
# Epoch 87/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0193 - mae: 0.0846 - rmse: 0.0846 - val_loss: 0.0183 - val_mae: 0.1182 - val_rmse: 0.1182
# Epoch 88/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0190 - mae: 0.0848 - rmse: 0.0848 - val_loss: 0.0181 - val_mae: 0.1176 - val_rmse: 0.1176
# Epoch 89/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0191 - mae: 0.0887 - rmse: 0.0887 - val_loss: 0.0182 - val_mae: 0.1174 - val_rmse: 0.1174
# Epoch 90/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0189 - mae: 0.0849 - rmse: 0.0849 - val_loss: 0.0184 - val_mae: 0.1187 - val_rmse: 0.1187
# Epoch 91/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0188 - mae: 0.0865 - rmse: 0.0865 - val_loss: 0.0182 - val_mae: 0.1178 - val_rmse: 0.1178
# Epoch 92/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0188 - mae: 0.0845 - rmse: 0.0845 - val_loss: 0.0180 - val_mae: 0.1163 - val_rmse: 0.1163
# Epoch 93/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0190 - mae: 0.0839 - rmse: 0.0839 - val_loss: 0.0185 - val_mae: 0.1200 - val_rmse: 0.1200
# Epoch 94/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0185 - mae: 0.0832 - rmse: 0.0832 - val_loss: 0.0182 - val_mae: 0.1190 - val_rmse: 0.1190
# Epoch 95/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0189 - mae: 0.0853 - rmse: 0.0853 - val_loss: 0.0182 - val_mae: 0.1165 - val_rmse: 0.1165
# Epoch 96/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.0839 - rmse: 0.0839 - val_loss: 0.0185 - val_mae: 0.1182 - val_rmse: 0.1182
# Epoch 97/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.0856 - rmse: 0.0856 - val_loss: 0.0182 - val_mae: 0.1187 - val_rmse: 0.1187
# Epoch 98/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0188 - mae: 0.0848 - rmse: 0.0848 - val_loss: 0.0184 - val_mae: 0.1180 - val_rmse: 0.1180
# Epoch 99/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0185 - mae: 0.0839 - rmse: 0.0839 - val_loss: 0.0185 - val_mae: 0.1207 - val_rmse: 0.1207
# Epoch 100/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0186 - mae: 0.0849 - rmse: 0.0849 - val_loss: 0.0178 - val_mae: 0.1171 - val_rmse: 0.1171
# Epoch 101/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0185 - mae: 0.0851 - rmse: 0.0851 - val_loss: 0.0190 - val_mae: 0.1228 - val_rmse: 0.1228
# Epoch 102/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0182 - mae: 0.0828 - rmse: 0.0828 - val_loss: 0.0180 - val_mae: 0.1172 - val_rmse: 0.1172
# Epoch 103/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0183 - mae: 0.0833 - rmse: 0.0833 - val_loss: 0.0181 - val_mae: 0.1179 - val_rmse: 0.1179
# Epoch 104/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0185 - mae: 0.0833 - rmse: 0.0833 - val_loss: 0.0182 - val_mae: 0.1183 - val_rmse: 0.1183
# Epoch 105/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0184 - mae: 0.0840 - rmse: 0.0840 - val_loss: 0.0187 - val_mae: 0.1209 - val_rmse: 0.1209
# Epoch 106/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0182 - mae: 0.0832 - rmse: 0.0832 - val_loss: 0.0186 - val_mae: 0.1204 - val_rmse: 0.1204
# Epoch 107/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0186 - mae: 0.0835 - rmse: 0.0835 - val_loss: 0.0182 - val_mae: 0.1190 - val_rmse: 0.1190
# Epoch 108/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0180 - mae: 0.0832 - rmse: 0.0832 - val_loss: 0.0188 - val_mae: 0.1172 - val_rmse: 0.1172
# Epoch 109/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.0859 - rmse: 0.0859 - val_loss: 0.0180 - val_mae: 0.1168 - val_rmse: 0.1168
# Epoch 110/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0183 - mae: 0.0838 - rmse: 0.0838 - val_loss: 0.0181 - val_mae: 0.1170 - val_rmse: 0.1170
# Epoch 111/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0184 - mae: 0.0848 - rmse: 0.0848 - val_loss: 0.0178 - val_mae: 0.1164 - val_rmse: 0.1164
# Epoch 112/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0183 - mae: 0.0829 - rmse: 0.0829 - val_loss: 0.0186 - val_mae: 0.1205 - val_rmse: 0.1205
# Epoch 113/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0182 - mae: 0.0829 - rmse: 0.0829 - val_loss: 0.0181 - val_mae: 0.1182 - val_rmse: 0.1182
# Epoch 114/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0181 - mae: 0.0838 - rmse: 0.0838 - val_loss: 0.0189 - val_mae: 0.1216 - val_rmse: 0.1216
# Epoch 115/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0180 - mae: 0.0831 - rmse: 0.0831 - val_loss: 0.0183 - val_mae: 0.1161 - val_rmse: 0.1161
# Epoch 116/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0182 - mae: 0.0854 - rmse: 0.0854 - val_loss: 0.0183 - val_mae: 0.1187 - val_rmse: 0.1187
# Epoch 117/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0179 - mae: 0.0839 - rmse: 0.0839 - val_loss: 0.0188 - val_mae: 0.1225 - val_rmse: 0.1225
# Epoch 118/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0180 - mae: 0.0836 - rmse: 0.0836 - val_loss: 0.0200 - val_mae: 0.1272 - val_rmse: 0.1272
# Epoch 119/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0180 - mae: 0.0829 - rmse: 0.0829 - val_loss: 0.0180 - val_mae: 0.1169 - val_rmse: 0.1169
# Epoch 120/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0181 - mae: 0.0840 - rmse: 0.0840 - val_loss: 0.0186 - val_mae: 0.1212 - val_rmse: 0.1212
# Epoch 121/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0181 - mae: 0.0826 - rmse: 0.0826 - val_loss: 0.0182 - val_mae: 0.1185 - val_rmse: 0.1185
# Epoch 122/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.0825 - rmse: 0.0825 - val_loss: 0.0183 - val_mae: 0.1179 - val_rmse: 0.1179
# Epoch 123/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0178 - mae: 0.0837 - rmse: 0.0837 - val_loss: 0.0189 - val_mae: 0.1221 - val_rmse: 0.1221
# Epoch 124/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0177 - mae: 0.0836 - rmse: 0.0836 - val_loss: 0.0192 - val_mae: 0.1233 - val_rmse: 0.1233
# Epoch 125/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0177 - mae: 0.0831 - rmse: 0.0831 - val_loss: 0.0189 - val_mae: 0.1221 - val_rmse: 0.1221
# Epoch 126/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0177 - mae: 0.0829 - rmse: 0.0829 - val_loss: 0.0193 - val_mae: 0.1247 - val_rmse: 0.1247
# Epoch 127/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.0810 - rmse: 0.0810 - val_loss: 0.0196 - val_mae: 0.1258 - val_rmse: 0.1258
# Epoch 128/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.0822 - rmse: 0.0822 - val_loss: 0.0186 - val_mae: 0.1213 - val_rmse: 0.1213
# Epoch 129/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.0816 - rmse: 0.0816 - val_loss: 0.0192 - val_mae: 0.1240 - val_rmse: 0.1240
# Epoch 130/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0172 - mae: 0.0823 - rmse: 0.0823 - val_loss: 0.0187 - val_mae: 0.1181 - val_rmse: 0.1181
# Epoch 131/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0176 - mae: 0.0821 - rmse: 0.0821 - val_loss: 0.0184 - val_mae: 0.1196 - val_rmse: 0.1196
# Epoch 132/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0174 - mae: 0.0807 - rmse: 0.0807 - val_loss: 0.0187 - val_mae: 0.1214 - val_rmse: 0.1214
# Epoch 133/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0174 - mae: 0.0807 - rmse: 0.0807 - val_loss: 0.0181 - val_mae: 0.1182 - val_rmse: 0.1182
# Epoch 134/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0174 - mae: 0.0836 - rmse: 0.0836 - val_loss: 0.0180 - val_mae: 0.1164 - val_rmse: 0.1164
# Epoch 135/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0172 - mae: 0.0810 - rmse: 0.0810 - val_loss: 0.0185 - val_mae: 0.1196 - val_rmse: 0.1196
# Epoch 136/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0171 - mae: 0.0817 - rmse: 0.0817 - val_loss: 0.0181 - val_mae: 0.1167 - val_rmse: 0.1167
# Epoch 137/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0173 - mae: 0.0806 - rmse: 0.0806 - val_loss: 0.0184 - val_mae: 0.1202 - val_rmse: 0.1202
# Epoch 138/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0171 - mae: 0.0819 - rmse: 0.0819 - val_loss: 0.0179 - val_mae: 0.1172 - val_rmse: 0.1172
# Epoch 139/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0170 - mae: 0.0798 - rmse: 0.0798 - val_loss: 0.0179 - val_mae: 0.1145 - val_rmse: 0.1145
# Epoch 140/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0170 - mae: 0.0819 - rmse: 0.0819 - val_loss: 0.0180 - val_mae: 0.1179 - val_rmse: 0.1179
# Epoch 141/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0170 - mae: 0.0797 - rmse: 0.0797 - val_loss: 0.0179 - val_mae: 0.1155 - val_rmse: 0.1155
# Epoch 142/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0167 - mae: 0.0808 - rmse: 0.0808 - val_loss: 0.0184 - val_mae: 0.1207 - val_rmse: 0.1207
# Epoch 143/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0168 - mae: 0.0815 - rmse: 0.0815 - val_loss: 0.0185 - val_mae: 0.1165 - val_rmse: 0.1165
# Epoch 144/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0169 - mae: 0.0820 - rmse: 0.0820 - val_loss: 0.0185 - val_mae: 0.1191 - val_rmse: 0.1191
# Epoch 145/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0166 - mae: 0.0817 - rmse: 0.0817 - val_loss: 0.0190 - val_mae: 0.1226 - val_rmse: 0.1226
# Epoch 146/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0166 - mae: 0.0801 - rmse: 0.0801 - val_loss: 0.0182 - val_mae: 0.1187 - val_rmse: 0.1187
# Epoch 147/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0167 - mae: 0.0800 - rmse: 0.0800 - val_loss: 0.0181 - val_mae: 0.1185 - val_rmse: 0.1185
# Epoch 148/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0165 - mae: 0.0801 - rmse: 0.0801 - val_loss: 0.0215 - val_mae: 0.1337 - val_rmse: 0.1337
# Epoch 149/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0166 - mae: 0.0804 - rmse: 0.0804 - val_loss: 0.0181 - val_mae: 0.1190 - val_rmse: 0.1190
# Epoch 150/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0166 - mae: 0.0796 - rmse: 0.0796 - val_loss: 0.0181 - val_mae: 0.1175 - val_rmse: 0.1175
# Epoch 151/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0164 - mae: 0.0789 - rmse: 0.0789 - val_loss: 0.0184 - val_mae: 0.1168 - val_rmse: 0.1168
# Epoch 152/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0164 - mae: 0.0814 - rmse: 0.0814 - val_loss: 0.0194 - val_mae: 0.1261 - val_rmse: 0.1261
# Epoch 153/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0165 - mae: 0.0784 - rmse: 0.0784 - val_loss: 0.0178 - val_mae: 0.1164 - val_rmse: 0.1164
# Epoch 154/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0163 - mae: 0.0786 - rmse: 0.0786 - val_loss: 0.0182 - val_mae: 0.1201 - val_rmse: 0.1201
# Epoch 155/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0163 - mae: 0.0798 - rmse: 0.0798 - val_loss: 0.0188 - val_mae: 0.1235 - val_rmse: 0.1235
# Epoch 156/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0165 - mae: 0.0802 - rmse: 0.0802 - val_loss: 0.0185 - val_mae: 0.1220 - val_rmse: 0.1220
# Epoch 157/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0162 - mae: 0.0792 - rmse: 0.0792 - val_loss: 0.0180 - val_mae: 0.1183 - val_rmse: 0.1183
# Epoch 158/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0162 - mae: 0.0793 - rmse: 0.0793 - val_loss: 0.0180 - val_mae: 0.1189 - val_rmse: 0.1189
# Epoch 159/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0159 - mae: 0.0789 - rmse: 0.0789 - val_loss: 0.0191 - val_mae: 0.1245 - val_rmse: 0.1245
# Epoch 160/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0161 - mae: 0.0792 - rmse: 0.0792 - val_loss: 0.0181 - val_mae: 0.1175 - val_rmse: 0.1175
# Epoch 161/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0160 - mae: 0.0781 - rmse: 0.0781 - val_loss: 0.0181 - val_mae: 0.1173 - val_rmse: 0.1173
# Epoch 162/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0158 - mae: 0.0775 - rmse: 0.0775 - val_loss: 0.0177 - val_mae: 0.1160 - val_rmse: 0.1160
# Epoch 163/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0159 - mae: 0.0788 - rmse: 0.0788 - val_loss: 0.0183 - val_mae: 0.1205 - val_rmse: 0.1205
# Epoch 164/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0155 - mae: 0.0790 - rmse: 0.0790 - val_loss: 0.0172 - val_mae: 0.1160 - val_rmse: 0.1160
# Epoch 165/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0155 - mae: 0.0777 - rmse: 0.0777 - val_loss: 0.0171 - val_mae: 0.1145 - val_rmse: 0.1145
# Epoch 166/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0155 - mae: 0.0785 - rmse: 0.0785 - val_loss: 0.0187 - val_mae: 0.1225 - val_rmse: 0.1225
# Epoch 167/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0156 - mae: 0.0774 - rmse: 0.0774 - val_loss: 0.0179 - val_mae: 0.1187 - val_rmse: 0.1187
# Epoch 168/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0155 - mae: 0.0787 - rmse: 0.0787 - val_loss: 0.0183 - val_mae: 0.1199 - val_rmse: 0.1199
# Epoch 169/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0153 - mae: 0.0765 - rmse: 0.0765 - val_loss: 0.0179 - val_mae: 0.1191 - val_rmse: 0.1191
# Epoch 170/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0148 - mae: 0.0762 - rmse: 0.0762 - val_loss: 0.0179 - val_mae: 0.1160 - val_rmse: 0.1160
# Epoch 171/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0151 - mae: 0.0755 - rmse: 0.0755 - val_loss: 0.0180 - val_mae: 0.1179 - val_rmse: 0.1179
# Epoch 172/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0151 - mae: 0.0757 - rmse: 0.0757 - val_loss: 0.0168 - val_mae: 0.1143 - val_rmse: 0.1143
# Epoch 173/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0151 - mae: 0.0766 - rmse: 0.0766 - val_loss: 0.0167 - val_mae: 0.1136 - val_rmse: 0.1136
# Epoch 174/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0151 - mae: 0.0751 - rmse: 0.0751 - val_loss: 0.0171 - val_mae: 0.1156 - val_rmse: 0.1156
# Epoch 175/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0146 - mae: 0.0762 - rmse: 0.0762 - val_loss: 0.0170 - val_mae: 0.1158 - val_rmse: 0.1158
# Epoch 176/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0150 - mae: 0.0769 - rmse: 0.0769 - val_loss: 0.0164 - val_mae: 0.1132 - val_rmse: 0.1132
# Epoch 177/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0144 - mae: 0.0729 - rmse: 0.0729 - val_loss: 0.0160 - val_mae: 0.1112 - val_rmse: 0.1112
# Epoch 178/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0145 - mae: 0.0744 - rmse: 0.0744 - val_loss: 0.0160 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 179/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0143 - mae: 0.0732 - rmse: 0.0732 - val_loss: 0.0165 - val_mae: 0.1132 - val_rmse: 0.1132
# Epoch 180/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0143 - mae: 0.0738 - rmse: 0.0738 - val_loss: 0.0157 - val_mae: 0.1100 - val_rmse: 0.1100
# Epoch 181/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0142 - mae: 0.0747 - rmse: 0.0747 - val_loss: 0.0159 - val_mae: 0.1110 - val_rmse: 0.1110
# Epoch 182/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0142 - mae: 0.0720 - rmse: 0.0720 - val_loss: 0.0162 - val_mae: 0.1121 - val_rmse: 0.1121
# Epoch 183/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0141 - mae: 0.0717 - rmse: 0.0717 - val_loss: 0.0155 - val_mae: 0.1096 - val_rmse: 0.1096
# Epoch 184/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0139 - mae: 0.0734 - rmse: 0.0734 - val_loss: 0.0155 - val_mae: 0.1091 - val_rmse: 0.1091
# Epoch 185/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0137 - mae: 0.0710 - rmse: 0.0710 - val_loss: 0.0150 - val_mae: 0.1075 - val_rmse: 0.1075
# Epoch 186/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0136 - mae: 0.0708 - rmse: 0.0708 - val_loss: 0.0139 - val_mae: 0.1035 - val_rmse: 0.1035
# Epoch 187/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0138 - mae: 0.0731 - rmse: 0.0731 - val_loss: 0.0160 - val_mae: 0.1111 - val_rmse: 0.1111
# Epoch 188/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0134 - mae: 0.0716 - rmse: 0.0716 - val_loss: 0.0158 - val_mae: 0.1104 - val_rmse: 0.1104
# Epoch 189/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0136 - mae: 0.0717 - rmse: 0.0717 - val_loss: 0.0148 - val_mae: 0.1063 - val_rmse: 0.1063
# Epoch 190/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0132 - mae: 0.0725 - rmse: 0.0725 - val_loss: 0.0159 - val_mae: 0.1102 - val_rmse: 0.1102
# Epoch 191/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0128 - mae: 0.0693 - rmse: 0.0693 - val_loss: 0.0151 - val_mae: 0.1088 - val_rmse: 0.1088
# Epoch 192/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0129 - mae: 0.0710 - rmse: 0.0710 - val_loss: 0.0140 - val_mae: 0.1030 - val_rmse: 0.1030
# Epoch 193/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0128 - mae: 0.0687 - rmse: 0.0687 - val_loss: 0.0151 - val_mae: 0.1085 - val_rmse: 0.1085
# Epoch 194/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0129 - mae: 0.0707 - rmse: 0.0707 - val_loss: 0.0144 - val_mae: 0.1050 - val_rmse: 0.1050
# Epoch 195/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0128 - mae: 0.0695 - rmse: 0.0695 - val_loss: 0.0141 - val_mae: 0.1047 - val_rmse: 0.1047
# Epoch 196/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0125 - mae: 0.0677 - rmse: 0.0677 - val_loss: 0.0155 - val_mae: 0.1095 - val_rmse: 0.1095
# Epoch 197/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0123 - mae: 0.0676 - rmse: 0.0676 - val_loss: 0.0151 - val_mae: 0.1065 - val_rmse: 0.1065
# Epoch 198/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0124 - mae: 0.0692 - rmse: 0.0692 - val_loss: 0.0186 - val_mae: 0.1173 - val_rmse: 0.1173
# Epoch 199/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0126 - mae: 0.0686 - rmse: 0.0686 - val_loss: 0.0140 - val_mae: 0.1045 - val_rmse: 0.1045
# Epoch 200/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0125 - mae: 0.0701 - rmse: 0.0701 - val_loss: 0.0151 - val_mae: 0.1083 - val_rmse: 0.1083
# Epoch 201/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0120 - mae: 0.0666 - rmse: 0.0666 - val_loss: 0.0114 - val_mae: 0.0931 - val_rmse: 0.0931
# Epoch 202/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0121 - mae: 0.0684 - rmse: 0.0684 - val_loss: 0.0143 - val_mae: 0.1012 - val_rmse: 0.1012
# Epoch 203/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0122 - mae: 0.0671 - rmse: 0.0671 - val_loss: 0.0128 - val_mae: 0.0989 - val_rmse: 0.0989
# Epoch 204/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0119 - mae: 0.0670 - rmse: 0.0670 - val_loss: 0.0151 - val_mae: 0.1075 - val_rmse: 0.1075
# Epoch 205/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0120 - mae: 0.0669 - rmse: 0.0669 - val_loss: 0.0126 - val_mae: 0.0971 - val_rmse: 0.0971
# Epoch 206/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0116 - mae: 0.0655 - rmse: 0.0655 - val_loss: 0.0159 - val_mae: 0.1103 - val_rmse: 0.1103
# Epoch 207/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0115 - mae: 0.0663 - rmse: 0.0663 - val_loss: 0.0119 - val_mae: 0.0931 - val_rmse: 0.0931
# Epoch 208/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0118 - mae: 0.0660 - rmse: 0.0660 - val_loss: 0.0131 - val_mae: 0.1009 - val_rmse: 0.1009
# Epoch 209/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0114 - mae: 0.0641 - rmse: 0.0641 - val_loss: 0.0130 - val_mae: 0.1008 - val_rmse: 0.1008
# Epoch 210/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0115 - mae: 0.0668 - rmse: 0.0668 - val_loss: 0.0130 - val_mae: 0.1006 - val_rmse: 0.1006
# Epoch 211/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0114 - mae: 0.0645 - rmse: 0.0645 - val_loss: 0.0117 - val_mae: 0.0934 - val_rmse: 0.0934
# Epoch 212/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0114 - mae: 0.0661 - rmse: 0.0661 - val_loss: 0.0112 - val_mae: 0.0919 - val_rmse: 0.0919
# Epoch 213/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0115 - mae: 0.0659 - rmse: 0.0659 - val_loss: 0.0129 - val_mae: 0.0999 - val_rmse: 0.0999
# Epoch 214/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0115 - mae: 0.0673 - rmse: 0.0673 - val_loss: 0.0120 - val_mae: 0.0935 - val_rmse: 0.0935
# Epoch 215/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0110 - mae: 0.0645 - rmse: 0.0645 - val_loss: 0.0121 - val_mae: 0.0923 - val_rmse: 0.0923
# Epoch 216/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0108 - mae: 0.0626 - rmse: 0.0626 - val_loss: 0.0179 - val_mae: 0.1139 - val_rmse: 0.1139
# Epoch 217/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0112 - mae: 0.0655 - rmse: 0.0655 - val_loss: 0.0121 - val_mae: 0.0947 - val_rmse: 0.0947
# Epoch 218/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0110 - mae: 0.0634 - rmse: 0.0634 - val_loss: 0.0144 - val_mae: 0.1044 - val_rmse: 0.1044
# Epoch 219/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0109 - mae: 0.0639 - rmse: 0.0639 - val_loss: 0.0149 - val_mae: 0.1047 - val_rmse: 0.1047
# Epoch 220/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0112 - mae: 0.0651 - rmse: 0.0651 - val_loss: 0.0126 - val_mae: 0.0983 - val_rmse: 0.0983
# Epoch 221/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0107 - mae: 0.0636 - rmse: 0.0636 - val_loss: 0.0147 - val_mae: 0.1037 - val_rmse: 0.1037
# Epoch 222/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0107 - mae: 0.0647 - rmse: 0.0647 - val_loss: 0.0155 - val_mae: 0.1077 - val_rmse: 0.1077
# Epoch 223/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0109 - mae: 0.0645 - rmse: 0.0645 - val_loss: 0.0140 - val_mae: 0.1024 - val_rmse: 0.1024
# Epoch 224/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0107 - mae: 0.0659 - rmse: 0.0659 - val_loss: 0.0130 - val_mae: 0.0992 - val_rmse: 0.0992
# Epoch 225/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0104 - mae: 0.0616 - rmse: 0.0616 - val_loss: 0.0152 - val_mae: 0.1066 - val_rmse: 0.1066
# Epoch 226/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0107 - mae: 0.0637 - rmse: 0.0637 - val_loss: 0.0138 - val_mae: 0.1021 - val_rmse: 0.1021
# Epoch 227/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0105 - mae: 0.0634 - rmse: 0.0634 - val_loss: 0.0113 - val_mae: 0.0904 - val_rmse: 0.0904
# Epoch 228/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0103 - mae: 0.0631 - rmse: 0.0631 - val_loss: 0.0124 - val_mae: 0.0968 - val_rmse: 0.0968
# Epoch 229/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0105 - mae: 0.0625 - rmse: 0.0625 - val_loss: 0.0123 - val_mae: 0.0960 - val_rmse: 0.0960
# Epoch 230/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0102 - mae: 0.0629 - rmse: 0.0629 - val_loss: 0.0114 - val_mae: 0.0922 - val_rmse: 0.0922
# Epoch 231/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0100 - mae: 0.0616 - rmse: 0.0616 - val_loss: 0.0134 - val_mae: 0.1004 - val_rmse: 0.1004
# Epoch 232/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0100 - mae: 0.0617 - rmse: 0.0617 - val_loss: 0.0110 - val_mae: 0.0896 - val_rmse: 0.0896
# Epoch 233/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0103 - mae: 0.0615 - rmse: 0.0615 - val_loss: 0.0123 - val_mae: 0.0955 - val_rmse: 0.0955
# Epoch 234/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0104 - mae: 0.0639 - rmse: 0.0639 - val_loss: 0.0135 - val_mae: 0.1004 - val_rmse: 0.1004
# Epoch 235/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0101 - mae: 0.0616 - rmse: 0.0616 - val_loss: 0.0115 - val_mae: 0.0924 - val_rmse: 0.0924
# Epoch 236/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0101 - mae: 0.0636 - rmse: 0.0636 - val_loss: 0.0143 - val_mae: 0.1021 - val_rmse: 0.1021
# Epoch 237/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0099 - mae: 0.0613 - rmse: 0.0613 - val_loss: 0.0138 - val_mae: 0.1004 - val_rmse: 0.1004
# Epoch 238/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0098 - mae: 0.0618 - rmse: 0.0618 - val_loss: 0.0109 - val_mae: 0.0896 - val_rmse: 0.0896
# Epoch 239/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0099 - mae: 0.0633 - rmse: 0.0633 - val_loss: 0.0107 - val_mae: 0.0890 - val_rmse: 0.0890
# Epoch 240/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0094 - mae: 0.0573 - rmse: 0.0573 - val_loss: 0.0130 - val_mae: 0.0971 - val_rmse: 0.0971
# Epoch 241/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0097 - mae: 0.0615 - rmse: 0.0615 - val_loss: 0.0128 - val_mae: 0.0982 - val_rmse: 0.0982
# Epoch 242/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0097 - mae: 0.0600 - rmse: 0.0600 - val_loss: 0.0125 - val_mae: 0.0956 - val_rmse: 0.0956
# Epoch 243/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0095 - mae: 0.0583 - rmse: 0.0583 - val_loss: 0.0120 - val_mae: 0.0921 - val_rmse: 0.0921
# Epoch 244/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0096 - mae: 0.0626 - rmse: 0.0626 - val_loss: 0.0165 - val_mae: 0.1051 - val_rmse: 0.1051
# Epoch 245/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0096 - mae: 0.0593 - rmse: 0.0593 - val_loss: 0.0115 - val_mae: 0.0921 - val_rmse: 0.0921
# Epoch 246/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0094 - mae: 0.0620 - rmse: 0.0620 - val_loss: 0.0118 - val_mae: 0.0935 - val_rmse: 0.0935
# Epoch 247/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0092 - mae: 0.0601 - rmse: 0.0601 - val_loss: 0.0121 - val_mae: 0.0945 - val_rmse: 0.0945
# Epoch 248/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0094 - mae: 0.0613 - rmse: 0.0613 - val_loss: 0.0097 - val_mae: 0.0833 - val_rmse: 0.0833
# Epoch 249/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0092 - mae: 0.0591 - rmse: 0.0591 - val_loss: 0.0141 - val_mae: 0.1000 - val_rmse: 0.1000
# Epoch 250/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0091 - mae: 0.0579 - rmse: 0.0579 - val_loss: 0.0128 - val_mae: 0.0964 - val_rmse: 0.0964
# Epoch 251/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0091 - mae: 0.0599 - rmse: 0.0599 - val_loss: 0.0110 - val_mae: 0.0897 - val_rmse: 0.0897
# Epoch 252/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0093 - mae: 0.0611 - rmse: 0.0611 - val_loss: 0.0112 - val_mae: 0.0892 - val_rmse: 0.0892
# Epoch 253/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0090 - mae: 0.0586 - rmse: 0.0586 - val_loss: 0.0122 - val_mae: 0.0944 - val_rmse: 0.0944
# Epoch 254/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0094 - mae: 0.0629 - rmse: 0.0629 - val_loss: 0.0106 - val_mae: 0.0882 - val_rmse: 0.0882
# Epoch 255/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0088 - mae: 0.0578 - rmse: 0.0578 - val_loss: 0.0141 - val_mae: 0.0976 - val_rmse: 0.0976
# Epoch 256/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0088 - mae: 0.0610 - rmse: 0.0610 - val_loss: 0.0119 - val_mae: 0.0931 - val_rmse: 0.0931
# Epoch 257/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0086 - mae: 0.0579 - rmse: 0.0579 - val_loss: 0.0113 - val_mae: 0.0910 - val_rmse: 0.0910
# Epoch 258/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0088 - mae: 0.0594 - rmse: 0.0594 - val_loss: 0.0106 - val_mae: 0.0882 - val_rmse: 0.0882
# Epoch 259/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0088 - mae: 0.0586 - rmse: 0.0586 - val_loss: 0.0111 - val_mae: 0.0875 - val_rmse: 0.0875
# Epoch 260/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0089 - mae: 0.0580 - rmse: 0.0580 - val_loss: 0.0144 - val_mae: 0.0984 - val_rmse: 0.0984
# Epoch 261/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0088 - mae: 0.0590 - rmse: 0.0590 - val_loss: 0.0119 - val_mae: 0.0909 - val_rmse: 0.0909
# Epoch 262/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0086 - mae: 0.0567 - rmse: 0.0567 - val_loss: 0.0105 - val_mae: 0.0874 - val_rmse: 0.0874
# Epoch 263/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0086 - mae: 0.0580 - rmse: 0.0580 - val_loss: 0.0104 - val_mae: 0.0863 - val_rmse: 0.0863
# Epoch 264/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0080 - mae: 0.0568 - rmse: 0.0568 - val_loss: 0.0093 - val_mae: 0.0801 - val_rmse: 0.0801
# Epoch 265/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0084 - mae: 0.0567 - rmse: 0.0567 - val_loss: 0.0131 - val_mae: 0.0950 - val_rmse: 0.0950
# Epoch 266/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0083 - mae: 0.0577 - rmse: 0.0577 - val_loss: 0.0144 - val_mae: 0.0980 - val_rmse: 0.0980
# Epoch 267/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0085 - mae: 0.0585 - rmse: 0.0585 - val_loss: 0.0152 - val_mae: 0.1017 - val_rmse: 0.1017
# Epoch 268/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0082 - mae: 0.0573 - rmse: 0.0573 - val_loss: 0.0141 - val_mae: 0.0983 - val_rmse: 0.0983
# Epoch 269/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0081 - mae: 0.0576 - rmse: 0.0576 - val_loss: 0.0139 - val_mae: 0.0976 - val_rmse: 0.0976
# Epoch 270/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0084 - mae: 0.0572 - rmse: 0.0572 - val_loss: 0.0150 - val_mae: 0.1001 - val_rmse: 0.1001
# Epoch 271/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0081 - mae: 0.0560 - rmse: 0.0560 - val_loss: 0.0108 - val_mae: 0.0865 - val_rmse: 0.0865
# Epoch 272/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0082 - mae: 0.0564 - rmse: 0.0564 - val_loss: 0.0131 - val_mae: 0.0953 - val_rmse: 0.0953
# Epoch 273/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0080 - mae: 0.0564 - rmse: 0.0564 - val_loss: 0.0121 - val_mae: 0.0928 - val_rmse: 0.0928
# Epoch 274/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0082 - mae: 0.0567 - rmse: 0.0567 - val_loss: 0.0117 - val_mae: 0.0908 - val_rmse: 0.0908
# Epoch 275/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0081 - mae: 0.0568 - rmse: 0.0568 - val_loss: 0.0108 - val_mae: 0.0870 - val_rmse: 0.0870
# Epoch 276/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0080 - mae: 0.0555 - rmse: 0.0555 - val_loss: 0.0107 - val_mae: 0.0869 - val_rmse: 0.0869
# Epoch 277/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0082 - mae: 0.0594 - rmse: 0.0594 - val_loss: 0.0118 - val_mae: 0.0911 - val_rmse: 0.0911
# Epoch 278/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0079 - mae: 0.0571 - rmse: 0.0571 - val_loss: 0.0101 - val_mae: 0.0846 - val_rmse: 0.0846
# Epoch 279/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0076 - mae: 0.0555 - rmse: 0.0555 - val_loss: 0.0138 - val_mae: 0.0976 - val_rmse: 0.0976
# Epoch 280/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0079 - mae: 0.0553 - rmse: 0.0553 - val_loss: 0.0133 - val_mae: 0.0964 - val_rmse: 0.0964
# Epoch 281/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0078 - mae: 0.0581 - rmse: 0.0581 - val_loss: 0.0102 - val_mae: 0.0850 - val_rmse: 0.0850
# Epoch 282/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0076 - mae: 0.0541 - rmse: 0.0541 - val_loss: 0.0135 - val_mae: 0.0970 - val_rmse: 0.0970
# Epoch 283/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0080 - mae: 0.0590 - rmse: 0.0590 - val_loss: 0.0127 - val_mae: 0.0931 - val_rmse: 0.0931
# Epoch 284/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0078 - mae: 0.0557 - rmse: 0.0557 - val_loss: 0.0124 - val_mae: 0.0924 - val_rmse: 0.0924
# Epoch 285/500
# ...
# Epoch 407/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0053 - mae: 0.0473 - rmse: 0.0473 - val_loss: 0.0174 - val_mae: 0.1142 - val_rmse: 0.1142
# Epoch 408/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0051 - mae: 0.0467 - rmse: 0.0467 - val_loss: 0.0175 - val_mae: 0.1158 - val_rmse: 0.1158
# Epoch 409/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0050 - mae: 0.0463 - rmse: 0.0463 - val_loss: 0.0141 - val_mae: 0.1039 - val_rmse: 0.1039
# Epoch 410/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0050 - mae: 0.0469 - rmse: 0.0469 - val_loss: 0.0175 - val_mae: 0.1148 - val_rmse: 0.1148
# Epoch 411/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0455 - rmse: 0.0455 - val_loss: 0.0136 - val_mae: 0.0975 - val_rmse: 0.0975
# Epoch 412/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0051 - mae: 0.0466 - rmse: 0.0466 - val_loss: 0.0161 - val_mae: 0.1100 - val_rmse: 0.1100
# Epoch 413/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0440 - rmse: 0.0440 - val_loss: 0.0147 - val_mae: 0.0978 - val_rmse: 0.0978
# Epoch 414/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0050 - mae: 0.0457 - rmse: 0.0457 - val_loss: 0.0147 - val_mae: 0.1039 - val_rmse: 0.1039
# Epoch 415/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0051 - mae: 0.0456 - rmse: 0.0456 - val_loss: 0.0169 - val_mae: 0.1156 - val_rmse: 0.1156
# Epoch 416/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0050 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0135 - val_mae: 0.0931 - val_rmse: 0.0931
# Epoch 417/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0050 - mae: 0.0455 - rmse: 0.0455 - val_loss: 0.0158 - val_mae: 0.1109 - val_rmse: 0.1109
# Epoch 418/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0455 - rmse: 0.0455 - val_loss: 0.0165 - val_mae: 0.1138 - val_rmse: 0.1138
# Epoch 419/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0050 - mae: 0.0471 - rmse: 0.0471 - val_loss: 0.0131 - val_mae: 0.0983 - val_rmse: 0.0983
# Epoch 420/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0464 - rmse: 0.0464 - val_loss: 0.0153 - val_mae: 0.1101 - val_rmse: 0.1101
# Epoch 421/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0444 - rmse: 0.0444 - val_loss: 0.0143 - val_mae: 0.0967 - val_rmse: 0.0967
# Epoch 422/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0438 - rmse: 0.0438 - val_loss: 0.0155 - val_mae: 0.1089 - val_rmse: 0.1089
# Epoch 423/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0459 - rmse: 0.0459 - val_loss: 0.0169 - val_mae: 0.1135 - val_rmse: 0.1135
# Epoch 424/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0450 - rmse: 0.0450 - val_loss: 0.0141 - val_mae: 0.0993 - val_rmse: 0.0993
# Epoch 425/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0051 - mae: 0.0472 - rmse: 0.0472 - val_loss: 0.0170 - val_mae: 0.1145 - val_rmse: 0.1145
# Epoch 426/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0050 - mae: 0.0462 - rmse: 0.0462 - val_loss: 0.0148 - val_mae: 0.1043 - val_rmse: 0.1043
# Epoch 427/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0446 - rmse: 0.0446 - val_loss: 0.0167 - val_mae: 0.1124 - val_rmse: 0.1124
# Epoch 428/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0451 - rmse: 0.0451 - val_loss: 0.0164 - val_mae: 0.1123 - val_rmse: 0.1123
# Epoch 429/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0450 - rmse: 0.0450 - val_loss: 0.0155 - val_mae: 0.1100 - val_rmse: 0.1100
# Epoch 430/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0447 - rmse: 0.0447 - val_loss: 0.0147 - val_mae: 0.0968 - val_rmse: 0.0968
# Epoch 431/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0455 - rmse: 0.0455 - val_loss: 0.0141 - val_mae: 0.1012 - val_rmse: 0.1012
# Epoch 432/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0454 - rmse: 0.0454 - val_loss: 0.0155 - val_mae: 0.1096 - val_rmse: 0.1096
# Epoch 433/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0049 - mae: 0.0457 - rmse: 0.0457 - val_loss: 0.0166 - val_mae: 0.1127 - val_rmse: 0.1127
# Epoch 434/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0446 - rmse: 0.0446 - val_loss: 0.0150 - val_mae: 0.1044 - val_rmse: 0.1044
# Epoch 435/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0048 - mae: 0.0436 - rmse: 0.0436 - val_loss: 0.0144 - val_mae: 0.1015 - val_rmse: 0.1015
# Epoch 436/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0447 - rmse: 0.0447 - val_loss: 0.0169 - val_mae: 0.1129 - val_rmse: 0.1129
# Epoch 437/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0444 - rmse: 0.0444 - val_loss: 0.0174 - val_mae: 0.1162 - val_rmse: 0.1162
# Epoch 438/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0458 - rmse: 0.0458 - val_loss: 0.0161 - val_mae: 0.1060 - val_rmse: 0.1060
# Epoch 439/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0447 - rmse: 0.0447 - val_loss: 0.0168 - val_mae: 0.1092 - val_rmse: 0.1092
# Epoch 440/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0048 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0173 - val_mae: 0.1105 - val_rmse: 0.1105
# Epoch 441/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0467 - rmse: 0.0467 - val_loss: 0.0175 - val_mae: 0.1146 - val_rmse: 0.1146
# Epoch 442/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0459 - rmse: 0.0459 - val_loss: 0.0171 - val_mae: 0.1115 - val_rmse: 0.1115
# Epoch 443/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0440 - rmse: 0.0440 - val_loss: 0.0156 - val_mae: 0.1027 - val_rmse: 0.1027
# Epoch 444/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0435 - rmse: 0.0435 - val_loss: 0.0151 - val_mae: 0.1081 - val_rmse: 0.1081
# Epoch 445/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0046 - mae: 0.0439 - rmse: 0.0439 - val_loss: 0.0151 - val_mae: 0.1020 - val_rmse: 0.1020
# Epoch 446/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0455 - rmse: 0.0455 - val_loss: 0.0151 - val_mae: 0.1000 - val_rmse: 0.1000
# Epoch 447/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0441 - rmse: 0.0441 - val_loss: 0.0164 - val_mae: 0.1072 - val_rmse: 0.1072
# Epoch 448/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0446 - rmse: 0.0446 - val_loss: 0.0143 - val_mae: 0.1010 - val_rmse: 0.1010
# Epoch 449/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0179 - val_mae: 0.1157 - val_rmse: 0.1157
# Epoch 450/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0046 - mae: 0.0448 - rmse: 0.0448 - val_loss: 0.0142 - val_mae: 0.1040 - val_rmse: 0.1040
# Epoch 451/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0458 - rmse: 0.0458 - val_loss: 0.0149 - val_mae: 0.0992 - val_rmse: 0.0992
# Epoch 452/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0462 - rmse: 0.0462 - val_loss: 0.0164 - val_mae: 0.1068 - val_rmse: 0.1068
# Epoch 453/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0459 - rmse: 0.0459 - val_loss: 0.0152 - val_mae: 0.1085 - val_rmse: 0.1085
# Epoch 454/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0450 - rmse: 0.0450 - val_loss: 0.0166 - val_mae: 0.1131 - val_rmse: 0.1131
# Epoch 455/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0430 - rmse: 0.0430 - val_loss: 0.0163 - val_mae: 0.1062 - val_rmse: 0.1062
# Epoch 456/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0441 - rmse: 0.0441 - val_loss: 0.0164 - val_mae: 0.1065 - val_rmse: 0.1065
# Epoch 457/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0166 - val_mae: 0.1089 - val_rmse: 0.1089
# Epoch 458/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0440 - rmse: 0.0440 - val_loss: 0.0191 - val_mae: 0.1222 - val_rmse: 0.1222
# Epoch 459/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0049 - mae: 0.0455 - rmse: 0.0455 - val_loss: 0.0160 - val_mae: 0.1109 - val_rmse: 0.1109
# Epoch 460/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0147 - val_mae: 0.1014 - val_rmse: 0.1014
# Epoch 461/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0451 - rmse: 0.0451 - val_loss: 0.0166 - val_mae: 0.1052 - val_rmse: 0.1052
# Epoch 462/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0048 - mae: 0.0463 - rmse: 0.0463 - val_loss: 0.0155 - val_mae: 0.1066 - val_rmse: 0.1066
# Epoch 463/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0145 - val_mae: 0.1056 - val_rmse: 0.1056
# Epoch 464/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0438 - rmse: 0.0438 - val_loss: 0.0158 - val_mae: 0.1059 - val_rmse: 0.1059
# Epoch 465/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0148 - val_mae: 0.0986 - val_rmse: 0.0986
# Epoch 466/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0444 - rmse: 0.0444 - val_loss: 0.0157 - val_mae: 0.1045 - val_rmse: 0.1045
# Epoch 467/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0453 - rmse: 0.0453 - val_loss: 0.0155 - val_mae: 0.1026 - val_rmse: 0.1026
# Epoch 468/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0435 - rmse: 0.0435 - val_loss: 0.0159 - val_mae: 0.1102 - val_rmse: 0.1102
# Epoch 469/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0043 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0166 - val_mae: 0.1061 - val_rmse: 0.1061
# Epoch 470/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0456 - rmse: 0.0456 - val_loss: 0.0167 - val_mae: 0.1057 - val_rmse: 0.1057
# Epoch 471/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0435 - rmse: 0.0435 - val_loss: 0.0147 - val_mae: 0.1038 - val_rmse: 0.1038
# Epoch 472/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0450 - rmse: 0.0450 - val_loss: 0.0160 - val_mae: 0.1049 - val_rmse: 0.1049
# Epoch 473/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0442 - rmse: 0.0442 - val_loss: 0.0185 - val_mae: 0.1189 - val_rmse: 0.1189
# Epoch 474/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0436 - rmse: 0.0436 - val_loss: 0.0166 - val_mae: 0.1101 - val_rmse: 0.1101
# Epoch 475/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0044 - mae: 0.0429 - rmse: 0.0429 - val_loss: 0.0166 - val_mae: 0.1090 - val_rmse: 0.1090
# Epoch 476/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0432 - rmse: 0.0432 - val_loss: 0.0151 - val_mae: 0.1064 - val_rmse: 0.1064
# Epoch 477/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0438 - rmse: 0.0438 - val_loss: 0.0150 - val_mae: 0.1003 - val_rmse: 0.1003
# Epoch 478/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0046 - mae: 0.0431 - rmse: 0.0431 - val_loss: 0.0157 - val_mae: 0.1066 - val_rmse: 0.1066
# Epoch 479/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0446 - rmse: 0.0446 - val_loss: 0.0158 - val_mae: 0.1079 - val_rmse: 0.1079
# Epoch 480/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0428 - rmse: 0.0428 - val_loss: 0.0156 - val_mae: 0.1087 - val_rmse: 0.1087
# Epoch 481/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0432 - rmse: 0.0432 - val_loss: 0.0159 - val_mae: 0.1092 - val_rmse: 0.1092
# Epoch 482/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0440 - rmse: 0.0440 - val_loss: 0.0187 - val_mae: 0.1196 - val_rmse: 0.1196
# Epoch 483/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0425 - rmse: 0.0425 - val_loss: 0.0161 - val_mae: 0.1090 - val_rmse: 0.1090
# Epoch 484/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0443 - rmse: 0.0443 - val_loss: 0.0152 - val_mae: 0.1061 - val_rmse: 0.1061
# Epoch 485/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0043 - mae: 0.0421 - rmse: 0.0421 - val_loss: 0.0165 - val_mae: 0.1063 - val_rmse: 0.1063
# Epoch 486/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0436 - rmse: 0.0436 - val_loss: 0.0155 - val_mae: 0.1072 - val_rmse: 0.1072
# Epoch 487/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0436 - rmse: 0.0436 - val_loss: 0.0172 - val_mae: 0.1101 - val_rmse: 0.1101
# Epoch 488/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0045 - mae: 0.0427 - rmse: 0.0427 - val_loss: 0.0162 - val_mae: 0.1033 - val_rmse: 0.1033
# Epoch 489/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0441 - rmse: 0.0441 - val_loss: 0.0164 - val_mae: 0.1092 - val_rmse: 0.1092
# Epoch 490/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0042 - mae: 0.0421 - rmse: 0.0421 - val_loss: 0.0151 - val_mae: 0.0988 - val_rmse: 0.0988
# Epoch 491/500
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0045 - mae: 0.0445 - rmse: 0.0445 - val_loss: 0.0169 - val_mae: 0.1071 - val_rmse: 0.1071
# Epoch 492/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0434 - rmse: 0.0434 - val_loss: 0.0152 - val_mae: 0.1010 - val_rmse: 0.1010
# Epoch 493/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0044 - mae: 0.0431 - rmse: 0.0431 - val_loss: 0.0154 - val_mae: 0.1032 - val_rmse: 0.1032
# Epoch 494/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0043 - mae: 0.0426 - rmse: 0.0426 - val_loss: 0.0179 - val_mae: 0.1184 - val_rmse: 0.1184
# Epoch 495/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0439 - rmse: 0.0439 - val_loss: 0.0167 - val_mae: 0.1082 - val_rmse: 0.1082
# Epoch 496/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0436 - rmse: 0.0436 - val_loss: 0.0158 - val_mae: 0.1030 - val_rmse: 0.1030
# Epoch 497/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0044 - mae: 0.0445 - rmse: 0.0445 - val_loss: 0.0154 - val_mae: 0.1005 - val_rmse: 0.1005
# Epoch 498/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0045 - mae: 0.0435 - rmse: 0.0435 - val_loss: 0.0182 - val_mae: 0.1143 - val_rmse: 0.1143
# Epoch 499/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0044 - mae: 0.0417 - rmse: 0.0417 - val_loss: 0.0163 - val_mae: 0.1065 - val_rmse: 0.1065
# Epoch 500/500
# 239/239 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0451 - rmse: 0.0451 - val_loss: 0.0154 - val_mae: 0.1071 - val_rmse: 0.1071
# 学習時間: 375.844215631485

# %%
# model.save('covid19_gru_model.h5')
# files.download('covid19_gru_model.h5')

# %%
# === 学習推移の可視化 ===
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(np.arange(len(train_loss)), train_loss, label="train_loss")
plt.plot(np.arange(len(val_loss)), val_loss, label="val_loss")
plt.title('Training and Validation loss')
plt.ylim((0, 0.04))#add
plt.legend()
plt.show()

train_mae = history.history['mae']
val_mae = history.history['val_mae']

plt.plot(np.arange(len(train_mae)), train_mae, label="train_mae")
plt.plot(np.arange(len(val_mae)), val_mae, label="val_mae")
plt.title('Training and Validation mae')
plt.ylim((0, 0.2))#add
plt.legend()
plt.show()

train_rmse = history.history['rmse']
val_rmse = history.history['val_rmse']

plt.plot(np.arange(len(train_loss)), train_rmse, label="train_rmse")
plt.plot(np.arange(len(val_loss)), val_rmse, label="val_rmse")
plt.title('Training and Validation rmse')
plt.ylim((0, 0.2))#add
plt.legend()
plt.show()

# %%
#training predictions
predicted_past_data = model.predict(study_data)
train_inverse= scaler.inverse_transform(predicted_past_data)

#test predictions
upcoming_future=7
predictions = train_normalized[-window:].tolist()
predictions = np.array(predictions).reshape(-1, window, 1)
#予測をfor文で
for i in range(upcoming_future):
  predicted_future = model.predict(predictions)
  with open("in_out.txt",mode="a", encoding= "utf-8") as f:
    f.write("input to model:" + str(predictions) )
    f.write("output from model:" + str(predicted_future) )
  predictions = predictions.tolist()
  predictions = np.append(predictions,predicted_future)
  predictions = predictions[-window:]
  predictions = np.array(predictions).reshape(-1, window, 1)

predictions_infected_pepole = scaler.inverse_transform(np.array(predictions).reshape(-1,1))
predictions_infected_pepole
# Out:
# array([[622.44356084],
#        [700.54307142],
#        [661.33579418],
#        [479.37637481],
#        [348.69638187],
#        [475.0714663 ],
#        [538.46155924]])

# %%
x_all =np.arange('2020-01-23','2020-10-29', dtype='datetime64[D]').astype('datetime64[D]')
x_past_predict = np.arange('2020-01-30','2020-10-22', dtype='datetime64[D]').astype('datetime64[D]')#23-26
x_train = np.arange('2020-01-23','2020-10-22', dtype='datetime64[D]').astype('datetime64[D]')
x_test = np.arange('2020-10-22', '2020-10-29', dtype='datetime64[D]').astype('datetime64[D]')

# %%
sns.set()
COVID = plt.figure(figsize=(20,8))
plt.title("COVID-19 in Japan")
plt.grid(True)
plt.xlabel("Day")
plt.ylabel("Nunber of Person infected with corona virus")
plt.plot(x_all,data_at_japan_diff,'g',lw=3,label='daily_at_japan')
#plt.plot(x_train,train_original_data,label='train_data')
#plt.plot(x_test,test_original_data,label='test_data')
plt.plot(x_past_predict,train_inverse,color='b', ls='-',lw=3,alpha=0.7, label='past_predict')#+8かも
plt.plot(x_test, predictions_infected_pepole, 'r',lw=3,alpha=0.7,label='upcoming_future')
plt.legend(loc='upper left')
plt.show()

# %%
sns.set()
COVID = plt.figure(figsize=(20,8))
plt.title("COVID-19 in Japan")
plt.grid(True)
plt.xlabel("Day")
plt.ylabel("Nunber of Person infected with corona virus")
plt.plot(x_test,test_original_data,color='b', ls='-',lw=3,alpha=0.7, label='past_predict')
plt.plot(x_test, predictions_infected_pepole, 'r',lw=3,alpha=0.7,label='upcoming_future')
plt.show()

# %%
train_data = train_original_data[7:]
train_mae = mean_absolute_error(train_data, train_inverse)
train_mse = mean_squared_error(train_data, train_inverse)
train_rmse = np.sqrt(mean_squared_error(train_data, train_inverse))
train_r2 = r2_score(train_data, train_inverse)

test_mae = mean_absolute_error(test_original_data, predictions_infected_pepole)
test_mse = mean_squared_error(test_original_data, predictions_infected_pepole)
test_rmse = np.sqrt(mean_squared_error(test_original_data, predictions_infected_pepole))
test_r2 = r2_score(test_original_data, predictions_infected_pepole)

print('train_mae:'+str(train_mae))
print('train_mse:'+str(train_mse))
print('train_rmae:'+str(train_rmse))
print('train_r2:'+str(train_r2))
print('')
print('test_mae:'+str(test_mae))
print('test_mae:'+str(test_mse))
print('test_mae:'+str(test_rmse))
print('test_mae:'+str(test_r2))#r2 最も当てはまりの良い場合、1.0 となります (当てはまりの悪い場合、マイナスとなることもあります)
# Out:
# train_mae:41.19883907647957
# train_mse:4012.319790208999
# train_rmae:63.34287481800143
# train_r2:0.971596525398634
#
# test_mae:77.56555900403431
# test_mae:10721.233342192738
# test_mae:103.54338869378739
# test_mae:0.23745676820434491
